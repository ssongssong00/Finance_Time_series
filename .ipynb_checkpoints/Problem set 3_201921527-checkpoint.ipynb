# %% [markdown]
# # Problem set 3
#
# #### 학과 : e-비즈니스학과
# #### 학번 : 201921527
# #### 이름 : 박성우

# %% [markdown]
# ### 1. As indicated in the textbook, the ACF of a series with a unit root shows little tendency to decay. Nevertheless, it may difficult to detect a unit root in a series with a negative moving average. Consider the unit root process yt = yt−1 + εt − 0.8εt−1.

# %% [markdown]
# #### 1.a Iterate backward from yt to solve for yt in terms of the {εt} series and the initial condition y0.

# %%
from IPython.display import Image

# %%
Image('1_a.jpg')

# %% [markdown]
# #### 1.b Use your answer to (a) to derive the first few terms of the ACF.

# %%
Image('1_b.jpeg')

# %% [markdown]
# #### 1.c Explain how the negative MA term affects the shape of the ACF. In particular, explain how the series is “infinitely persistent” even though the coefficient of the ACF are far below unity.

# %%
Image('1_c.jpeg')

# %% [markdown]
# ---

# %% [markdown]
# ### Load packages

# %%
# Load data-preprocessing pacakages
import pandas as pd
import numpy as np

# Load visualization pacakage
import matplotlib.pyplot as plt

# Load modeling pacakages
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import grangercausalitytests

# ignore warning
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. The file QUARTERLY.XLSX contains the U.S. interest rate data used in Section 10 of Chapter 2. Form the spread st, by subtracting t-bill rate from the 5-year rate. Recall that the spread appeared to be quite persistent in that ρ1 = 0.86 and ρ2 = 0.68.

# %% [markdown]
# #### Data Load

# %%
df = pd.read_csv('QUARTERLY_PR3.csv')
df.set_index('Date',drop=True, inplace = True)
df
# Out:
#              FFR  Tbill  Tb1yr    r5   r10  PPINSA  Finished     CPI  CPICORE  \
# Date
# 1960-01-01  3.93   3.87   4.57  4.64  4.49   31.67     33.20   29.40    18.92
# 1960-04-01  3.70   2.99   3.87  4.30  4.26   31.73     33.40   29.57    19.00
# 1960-07-01  2.94   2.36   3.07  3.67  3.83   31.63     33.43   29.59    19.07
# 1960-10-01  2.30   2.31   2.99  3.75  3.89   31.70     33.67   29.78    19.14
# 1961-01-01  2.00   2.35   2.87  3.64  3.79   31.80     33.63   29.84    19.17
# ...          ...    ...    ...   ...   ...     ...       ...     ...      ...
# 2011-10-01  0.07   0.01   0.11  0.95  2.05  200.77    192.97  226.97   112.50
# 2012-01-01  0.10   0.07   0.16  0.90  2.04  202.17    193.73  228.27   113.12
# 2012-04-01  0.15   0.09   0.19  0.79  1.82  201.80    192.83  228.84   113.60
# 2012-07-01  0.14   0.10   0.18  0.67  1.64  202.40    195.20  230.03   113.91
# 2012-10-01  0.16   0.09   0.17  0.69  1.71  202.27    196.20  231.28   114.18
#
#               M1NSA     M2SA     M2NSA  Unemp  IndProd     RGDP   Potent  \
# Date
# 1960-01-01   140.53    896.1    299.40   5.13    23.93   2845.3   2824.2
# 1960-04-01   138.40    903.3    300.03   5.23    23.41   2832.0   2851.2
# 1960-07-01   139.60    919.4    305.50   5.53    23.02   2836.6   2878.7
# 1960-10-01   142.67    932.8    312.30   6.27    22.47   2800.2   2906.7
# 1961-01-01   142.23    948.9    317.10   6.80    22.13   2816.9   2934.8
# ...             ...      ...       ...    ...      ...      ...      ...
# 2011-10-01  2165.77  28787.3   9599.47   8.67    95.33  13441.0  14255.9
# 2012-01-01  2213.97  29238.6   9777.03   8.27    96.70  13506.4  14317.4
# 2012-04-01  2258.30  29611.6   9888.97   8.17    97.27  13548.5  14379.3
# 2012-07-01  2326.47  30251.4  10029.87   8.03    97.39  13652.5  14441.9
# 2012-10-01  2436.73  30938.8  10319.60   7.83    98.01  13665.4  14505.4
#
#             Deflator      Curr
# Date
# 1960-01-01    18.521    31.830
# 1960-04-01    18.579    31.862
# 1960-07-01    18.648    32.217
# 1960-10-01    18.700    32.624
# 1961-01-01    18.743    32.073
# ...              ...       ...
# 2011-10-01   113.987  1055.496
# 2012-01-01   114.599  1082.519
# 2012-04-01   115.035  1104.500
# 2012-07-01   115.810  1119.187
# 2012-10-01   116.089  1147.623
#
# [212 rows x 18 columns]

# %% [markdown]
# #### Visualization Tbill

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,212,15))
plt.plot(df['Tbill'])

# %% [markdown]
# #### Visualization r5

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,212,15))
plt.plot(df['r5'])

# %% [markdown]
# ##### spread 변수 생성

# %%
df['spread'] = df['Tbill'] - df['r5']
df = df.dropna()

# %% [markdown]
# #### Visualization spread

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,212,15))
plt.plot(df['spread'])

# %% [markdown]
# #### spread ACF plot

# %%
def acf_plot_coef(data, N_LAGS, pval):    
    auto = pd.Series(data.values)
    for i in range(0, N_LAGS+1):
        print(f"lag at {i}'s autocorrelation = ", round(auto.autocorr(lag=i),2))
        scatter = pd.DataFrame()
        scatter['lags'] = [i for i in range (1, N_LAGS +1)]
        scatter['autocorrelation'] = [ auto.autocorr(lag=i) for i in range(1, N_LAGS +1)]

    fig = plot_acf(data, lags=N_LAGS, alpha=pval)
    plt.xlabel(f'Lag at k (0 to {N_LAGS})')
    plt.ylabel("lag at k's autocorrelation")
    plt.scatter(x=scatter['lags'], y=scatter['autocorrelation'], edgecolors='red',linewidth=1, s=200, alpha = .5)
    plt.show()
    
acf_plot_coef(df['spread'], 10, 0.05)
# Out:
# lag at 0's autocorrelation =  1.0
# lag at 1's autocorrelation =  0.86
# lag at 2's autocorrelation =  0.68
# lag at 3's autocorrelation =  0.55
# lag at 4's autocorrelation =  0.41
# lag at 5's autocorrelation =  0.28
# lag at 6's autocorrelation =  0.15
# lag at 7's autocorrelation =  0.07
# lag at 8's autocorrelation =  0.04
# lag at 9's autocorrelation =  -0.03
# lag at 10's autocorrelation =  -0.13

# %% [markdown]
# - ACF plot을 시각화한 결과, 실제로 ρ1 = 0.86 and ρ2 = 0.68임을 알 수 있다.

# %% [markdown]
# #### 2.a One difficulty in performing a unit root test is to select the proper lag length. Using a maximum of 12 lags, estimate models of the form ∆st = a0 + γst−1 + Pβi∆st−i. Use the AIC and BIC methods to select lag lengths of 9, 1, and 8, respectively. In this case, does the lag length matter for the Dickey-Fuller test?

# %% [markdown]
# #### ADF test
# Null Hypotesis : Stationarity하지 않다. (단위근이 존재)
# Alternative Hypotesis : Stationarity하다. (단위근 존재 X)

# %%
# maxlag와 Lag criteria를 설정하고 ADF test를 진행하는 함수 생성
def adf_test(df, i, criteria):
    result  = adfuller(df.values, maxlag = i, autolag = criteria)
    print('ADF Statistics: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Best Lag :%d' % result[2])
    print(criteria + ' : %f' % result[5])
    print('Critical value:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key,value))

# %%
adf_test(df['spread'], 12, 'AIC')
# Out:
# ADF Statistics: -4.702604
# p-value: 0.000083
# Best Lag :9
# AIC : 275.457192
# Critical value:
# 	1%: -3.463
# 	5%: -2.876
# 	10%: -2.574

# %% [markdown]
# - p-value가 0.05보다 작기 때문에 Null Hypothesis를 reject할 수 있다.
# - 따라서 stationary하다.

# %%
adf_test(df['spread'], 12, 'BIC')
# Out:
# ADF Statistics: -4.750543
# p-value: 0.000068
# Best Lag :1
# BIC : 297.089896
# Critical value:
# 	1%: -3.462
# 	5%: -2.875
# 	10%: -2.574

# %% [markdown]
# - p-value가 0.05보다 작기 때문에 Null Hypothesis를 reject할 수 있다.
# - 따라서 stationary하다.

# %% [markdown]
# - spread에 대해서 AIC method를 사용하여 Augmented Dickey-Fuller test를 진행했을 때는 Best Lag가 9로 나타났고, BIC method를 사용하여 Augmented Dickey-Fuller test를 진행했을 때는 Best Lag가 1로 나타났다.
#
# - 어떤 Criteria를 사용하느냐에 따라 Best Lag length가 다르므로 AIC, BIC, Log-Likelihood 등을 모두 종합적으로 고려하여 최적의 lag length를 선택하는 것은 중요하다.

# %% [markdown]
# #### 2.b Use a lag length of 8 and perform an augmented Dickey-Fuller test of the spread. You should find (1). Is the spread stationary?

# %%
adf_test(df['spread'], 8, 'AIC')
# Out:
# ADF Statistics: -4.365749
# p-value: 0.000341
# Best Lag :8
# AIC : 278.241723
# Critical value:
# 	1%: -3.463
# 	5%: -2.876
# 	10%: -2.574

# %% [markdown]
# - p-value가 0.05보다 작기 때문에 Null Hypothesis를 reject할 수 있다.
# - 따라서 stationary하다.

# %% [markdown]
# #### 2.c Perform an augmented Dickey-Fuller test of the 5-year rate using seven lags. Is the 5-year rate stationary?

# %%
adf_test(df['r5'], 7, 'BIC')
# Out:
# ADF Statistics: -1.487999
# p-value: 0.539440
# Best Lag :3
# BIC : 356.213835
# Critical value:
# 	1%: -3.462
# 	5%: -2.876
# 	10%: -2.574

# %% [markdown]
# - p-value가 0.05보다 크기 때문에 Null Hypothesis를 reject할 수 없다.
# - 따라서 non-stationary하다.

# %% [markdown]
# #### 2.d Perform an augmented Dickey-Fuller test on the unemployment rate (UNEMP). If you use eight lagged changes you will find (2). Note that the t-statistic on β8 is -2.65.

# %%
adf_test(df['Unemp'], 8, 'AIC')
# Out:
# ADF Statistics: -2.254621
# p-value: 0.187021
# Best Lag :8
# AIC : 9.233003
# Critical value:
# 	1%: -3.463
# 	5%: -2.876
# 	10%: -2.574

# %% [markdown]
# - p-value가 0.05보다 크기 때문에 Null Hypothesis를 reject할 수 없다.
# - 따라서 non-stationary하다.

# %% [markdown]
# ### 3. This set of exercise uses data from the file entitled QUARTERLY.XLSX in order to estimate the dynamic effects of aggregate demand and supply shocks on industrial production and the inflation rate. Create the logarithmic change in the index of industrial production (indprod) as ∆lipt = ln(indprodt) − ln(indprodt−1) and the inflation rate (as measured by the CPI) as inft = log(cpit) − log(cpit−1).

# %% [markdown]
# #### Create the logarithmic change in the index of industrial production

# %%
df['yt_indprod'] = np.log(df['IndProd']) - np.log(df['IndProd'].shift(1))

# %% [markdown]
# #### Create the logarithmic change in the inflation rate as measured by the CPI

# %%
df['yt_cpi'] = np.log(df['CPI']) - np.log(df['CPI'].shift(1))

df.dropna(inplace = True)

# %%
df
# Out:
#              FFR  Tbill  Tb1yr    r5   r10  PPINSA  Finished     CPI  CPICORE  \
# Date
# 1960-04-01  3.70   2.99   3.87  4.30  4.26   31.73     33.40   29.57    19.00
# 1960-07-01  2.94   2.36   3.07  3.67  3.83   31.63     33.43   29.59    19.07
# 1960-10-01  2.30   2.31   2.99  3.75  3.89   31.70     33.67   29.78    19.14
# 1961-01-01  2.00   2.35   2.87  3.64  3.79   31.80     33.63   29.84    19.17
# 1961-04-01  1.73   2.30   2.94  3.62  3.79   31.47     33.33   29.83    19.23
# ...          ...    ...    ...   ...   ...     ...       ...     ...      ...
# 2011-10-01  0.07   0.01   0.11  0.95  2.05  200.77    192.97  226.97   112.50
# 2012-01-01  0.10   0.07   0.16  0.90  2.04  202.17    193.73  228.27   113.12
# 2012-04-01  0.15   0.09   0.19  0.79  1.82  201.80    192.83  228.84   113.60
# 2012-07-01  0.14   0.10   0.18  0.67  1.64  202.40    195.20  230.03   113.91
# 2012-10-01  0.16   0.09   0.17  0.69  1.71  202.27    196.20  231.28   114.18
#
#               M1NSA  ...     M2NSA  Unemp  IndProd     RGDP   Potent  \
# Date                 ...
# 1960-04-01   138.40  ...    300.03   5.23    23.41   2832.0   2851.2
# 1960-07-01   139.60  ...    305.50   5.53    23.02   2836.6   2878.7
# 1960-10-01   142.67  ...    312.30   6.27    22.47   2800.2   2906.7
# 1961-01-01   142.23  ...    317.10   6.80    22.13   2816.9   2934.8
# 1961-04-01   141.40  ...    320.97   7.00    23.00   2869.6   2962.9
# ...             ...  ...       ...    ...      ...      ...      ...
# 2011-10-01  2165.77  ...   9599.47   8.67    95.33  13441.0  14255.9
# 2012-01-01  2213.97  ...   9777.03   8.27    96.70  13506.4  14317.4
# 2012-04-01  2258.30  ...   9888.97   8.17    97.27  13548.5  14379.3
# 2012-07-01  2326.47  ...  10029.87   8.03    97.39  13652.5  14441.9
# 2012-10-01  2436.73  ...  10319.60   7.83    98.01  13665.4  14505.4
#
#             Deflator      Curr  spread  yt_indprod    yt_cpi
# Date
# 1960-04-01    18.579    31.862   -1.31   -0.021970  0.005766
# 1960-07-01    18.648    32.217   -1.31   -0.016800  0.000676
# 1960-10-01    18.700    32.624   -1.44   -0.024182  0.006401
# 1961-01-01    18.743    32.073   -1.29   -0.015247  0.002013
# 1961-04-01    18.785    32.131   -1.32    0.038560 -0.000335
# ...              ...       ...     ...         ...       ...
# 2011-10-01   113.987  1055.496   -0.94    0.012243  0.003487
# 2012-01-01   114.599  1082.519   -0.83    0.014269  0.005711
# 2012-04-01   115.035  1104.500   -0.70    0.005877  0.002494
# 2012-07-01   115.810  1119.187   -0.57    0.001233  0.005187
# 2012-10-01   116.089  1147.623   -0.60    0.006346  0.005419
#
# [211 rows x 21 columns]

# %% [markdown]
# #### Visualization IndProd

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,212,15))
plt.plot(df['IndProd'])

# %% [markdown]
# #### Visualization yt_indprod

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,212,15))
plt.plot(df['yt_indprod'])

# %% [markdown]
# #### Visualization CPI

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,212,15))
plt.plot(df['CPI'])

# %% [markdown]
# #### Visualization yt_cpi

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,212,15))
plt.plot(df['yt_cpi'])

# %% [markdown]
# #### 3.a Determine whether ∆lipt and inft are stationary.

# %% [markdown]
# ##### yt_indprod ADF test

# %%
def adf_test_1(df):
    result  = adfuller(df.values)
    print('ADF Statistics: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical value:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key,value))

# %%
adf_test_1(df['yt_indprod'])
# Out:
# ADF Statistics: -4.738741
# p-value: 0.000071
# Critical value:
# 	1%: -3.464
# 	5%: -2.876
# 	10%: -2.575

# %% [markdown]
# - p-value가 0.05보다 작기 때문에 Null Hypothesis를 reject할 수 있다.
# - 따라서 stationary하다.

# %% [markdown]
# ##### yt_cpi ADF test

# %%
adf_test_1(df['yt_cpi'])
# Out:
# ADF Statistics: -2.941870
# p-value: 0.040691
# Critical value:
# 	1%: -3.462
# 	5%: -2.876
# 	10%: -2.574

# %% [markdown]
# - p-value가 0.05보다 작기 때문에 Null Hypothesis를 reject할 수 있다.
# - 따라서 stationary하다.

# %% [markdown]
# #### 3.b Estimate the two-variable VAR using three lags of each variable and a constant and save the residuals. Verify that which lag (three or five) is selected by SBC, AIC, or any other lag selection criteria.

# %%
var = VAR(df[['yt_indprod','yt_cpi']])
var.select_order(maxlags=10).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# - yt_indprod와 yt_cpi에 대해서 ADF test를 진행한 결과, 모두 stationary process인 것으로 확인되었다.
# - 따라서 VAR 모형을 실시할 수 있다.
# - AIC, BIC, FPE, HQIC와 같은 lag selection criteria를 종합적으로 고려해본 결과, lag 3과 lag 5 중 lag를 선택할 수 있다.

# %%
fit = sm.tsa.VAR(df[['yt_indprod','yt_cpi']]).fit(maxlags=3) 
display(fit.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 06, Jun, 2023
# Time:                     22:58:48
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -19.2943
# Nobs:                     208.000    HQIC:                  -19.4281
# Log likelihood:           1453.69    FPE:                3.33458e-09
# AIC:                     -19.5190    Det(Omega_mle):     3.12098e-09
# --------------------------------------------------------------------
# Results for equation yt_indprod
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.008056         0.001648            4.888           0.000
# L1.yt_indprod         0.631566         0.069512            9.086           0.000
# L1.yt_cpi            -0.228092         0.178703           -1.276           0.202
# L2.yt_indprod        -0.180745         0.082902           -2.180           0.029
# L2.yt_cpi             0.078858         0.206024            0.383           0.702
# L3.yt_indprod         0.072784         0.067978            1.071           0.284
# L3.yt_cpi            -0.317861         0.180763           -1.758           0.079
# ================================================================================
#
# Results for equation yt_cpi
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.000534         0.000616            0.867           0.386
# L1.yt_indprod         0.097347         0.025967            3.749           0.000
# L1.yt_cpi             0.559711         0.066757            8.384           0.000
# L2.yt_indprod        -0.055449         0.030969           -1.790           0.073
# L2.yt_cpi             0.016199         0.076963            0.210           0.833
# L3.yt_indprod         0.027796         0.025394            1.095           0.274
# L3.yt_cpi             0.320813         0.067527            4.751           0.000
# ================================================================================
#
# Correlation matrix of residuals
#               yt_indprod    yt_cpi
# yt_indprod      1.000000  0.129968
# yt_cpi          0.129968  1.000000

# %%
fit = sm.tsa.VAR(df[['yt_indprod','yt_cpi']]).fit(maxlags=5) 
display(fit.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 06, Jun, 2023
# Time:                     22:58:48
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -19.2008
# Nobs:                     206.000    HQIC:                  -19.4125
# Log likelihood:           1451.69    FPE:                3.21306e-09
# AIC:                     -19.5562    Det(Omega_mle):     2.89557e-09
# --------------------------------------------------------------------
# Results for equation yt_indprod
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.007073         0.001805            3.918           0.000
# L1.yt_indprod         0.633728         0.070430            8.998           0.000
# L1.yt_cpi            -0.174458         0.187485           -0.931           0.352
# L2.yt_indprod        -0.157348         0.083212           -1.891           0.059
# L2.yt_cpi            -0.112799         0.214368           -0.526           0.599
# L3.yt_indprod         0.166397         0.082968            2.006           0.045
# L3.yt_cpi            -0.271786         0.205065           -1.325           0.185
# L4.yt_indprod        -0.074300         0.083233           -0.893           0.372
# L4.yt_cpi            -0.016607         0.211461           -0.079           0.937
# L5.yt_indprod        -0.068187         0.068130           -1.001           0.317
# L5.yt_cpi             0.205072         0.188467            1.088           0.277
# ================================================================================
#
# Results for equation yt_cpi
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.000026         0.000686            0.038           0.969
# L1.yt_indprod         0.095739         0.026761            3.578           0.000
# L1.yt_cpi             0.543497         0.071239            7.629           0.000
# L2.yt_indprod        -0.042425         0.031618           -1.342           0.180
# L2.yt_cpi            -0.019843         0.081453           -0.244           0.808
# L3.yt_indprod         0.003449         0.031525            0.109           0.913
# L3.yt_cpi             0.320233         0.077919            4.110           0.000
# L4.yt_indprod         0.034267         0.031626            1.084           0.279
# L4.yt_cpi            -0.091730         0.080349           -1.142           0.254
# L5.yt_indprod         0.024507         0.025887            0.947           0.344
# L5.yt_cpi             0.166386         0.071612            2.323           0.020
# ================================================================================
#
# Correlation matrix of residuals
#               yt_indprod    yt_cpi
# yt_indprod      1.000000  0.152807
# yt_cpi          0.152807  1.000000

# %% [markdown]
# Lag 3과 5로 VAR 모형을 모두 실시해 본 결과, criteria 값이 전체적으로 비슷하기 때문에 parsimonious한 model를 만들기 위해 lag 3을 선택하겠다.

# %% [markdown]
# ### 3.c Perform the Granger causality tests. Verify that the F-statistic for the test that inflation Grnager-causes industrial production is 4.82 (with a significance level of 0.003) and that Fstatistic for the test that industrial production Granger-inflation is 5.1050 (with a significance level 0.002).

# %% [markdown]
# #### Granger causality test
#
# Null Hypotesis : 한 변수가 다른 변수를 예측하는 데 도움이 되지 않는다.
# Alternative Hypotesis : 한 변수가 다른 변수를 예측하는 데 도움이 된다.

# %% [markdown]
# #### Inflation Granger-causes industrial production

# %%
sample_outs = grangercausalitytests(df[['yt_indprod','yt_cpi']], maxlag=3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=10.8763 , p=0.0011  , df_denom=207, df_num=1
# ssr based chi2 test:   chi2=11.0339 , p=0.0009  , df=1
# likelihood ratio test: chi2=10.7538 , p=0.0010  , df=1
# parameter F test:         F=10.8763 , p=0.0011  , df_denom=207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.2032  , p=0.0063  , df_denom=204, df_num=2
# ssr based chi2 test:   chi2=10.6615 , p=0.0048  , df=2
# likelihood ratio test: chi2=10.3985 , p=0.0055  , df=2
# parameter F test:         F=5.2032  , p=0.0063  , df_denom=204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.8191  , p=0.0029  , df_denom=201, df_num=3
# ssr based chi2 test:   chi2=14.9607 , p=0.0019  , df=3
# likelihood ratio test: chi2=14.4472 , p=0.0024  , df=3
# parameter F test:         F=4.8191  , p=0.0029  , df_denom=201, df_num=3

# %%
sample_outs[3][0]['ssr_ftest']
# Out:
# (4.81908484395867, 0.002911367624402613, 201.0, 3)

# %% [markdown]
# - Granger causality test 결과, F-statistic이 4.82이고, p-value가 유의수준 0.05하에서 0.003으로 작기 때문에 Null Hypothesis를 reject할 수 있다.
# - 따라서 Inflation이 Industrial Production을 예측하는 데 도움이 된다는 결과를 얻을 수 있다.

# %% [markdown]
# #### Industrial production Granger-causes Inflation

# %%
sample_outs_1 = grangercausalitytests(df[['yt_cpi','yt_indprod']], maxlag=3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.7363  , p=0.0996  , df_denom=207, df_num=1
# ssr based chi2 test:   chi2=2.7759  , p=0.0957  , df=1
# likelihood ratio test: chi2=2.7577  , p=0.0968  , df=1
# parameter F test:         F=2.7363  , p=0.0996  , df_denom=207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.3166  , p=0.0056  , df_denom=204, df_num=2
# ssr based chi2 test:   chi2=10.8938 , p=0.0043  , df=2
# likelihood ratio test: chi2=10.6194 , p=0.0049  , df=2
# parameter F test:         F=5.3166  , p=0.0056  , df_denom=204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.1050  , p=0.0020  , df_denom=201, df_num=3
# ssr based chi2 test:   chi2=15.8483 , p=0.0012  , df=3
# likelihood ratio test: chi2=15.2735 , p=0.0016  , df=3
# parameter F test:         F=5.1050  , p=0.0020  , df_denom=201, df_num=3

# %%
sample_outs_1[3][0]['ssr_ftest']
# Out:
# (5.1049712525851785, 0.0019996218178981585, 201.0, 3)

# %% [markdown]
# - Granger causality test 결과, F-statistic이 5.1050이고, p-value가 유의수준 0.05하에서 0.002으로 작기 때문에 Null Hypothesis를 reject할 수 있다.
# - 따라서 Industrial Production이 Inflation을 예측하는 데 도움이 된다는 결과를 얻을 수 있다.

# %% [markdown]
# 최종적으로 Inflation과 Industrial Production은 서로 Granger 인과영향을 미친다.

# %% [markdown]
# ### 4. Now, I assume that you have set your objective (theme) of your term paper. By now, you must have your data on two (X and Y , at least) or more variables in your hands. You have already held some statistical analyses based on your problem sets Take the two time series that you selected last week, take their first differences if they are nonstationary, and select an appropriate VAR model. You may refer to the following questions to summarize your results.

# %% [markdown]
# ### 분석 개요

# %% [markdown]
# 2022년 5월 23일에 한국거래소는 유가증권시장 상장 리츠 종목 중 시가총액 상위 10개 종목을 유동 시가총액으로 가중해 산출한 지수인 **리츠 TOP10 지수**를 발표했다. 리츠 상품은 리츠 회사의 재정 상황, 기초 자산의 건전성, 거시경제 상황에 많은 영향을 받는 상품이다. 1년이 되가는 이 시점에서 2022년 5월 23일부터 2023년 5월 22일까지의 237일 간의 일간 시계열 자료를 바탕으로 리츠 TOP10 지수 수익률에 영향을 미치는 요인을 분석해보고자 한다.

# %% [markdown]
# #### 사용하는 데이터
# 1. KRX 리츠 TOP10 지수
# 2. KRX 건설 지수
# 3. 한국은행 뉴스심리지수
# 4. 장단기금리차(T10Y2Y)

# %% [markdown]
# ##### Data Load and preprocessing

# %% [markdown]
# #### KRX 리츠 TOP10지수

# %%
KRX_REITs = pd.read_excel('KRX_리츠TOP10지수.xlsx')

# %%
KRX_REITs = KRX_REITs.sort_index(ascending=False)
KRX_REITs.reset_index(drop = True, inplace = True)
KRX_REITs.set_index('일자',drop=True, inplace = True)

# %%
KRX_REITs
# Out:
#                  종가     대비   등락률       시가       고가       저가      거래량  \
# 일자
# 2022/05/23  1187.49  -4.87 -0.41  1188.66  1189.77  1183.90  1724259
# 2022/05/24  1194.48   6.99  0.59  1186.89  1197.45  1185.45  1787565
# 2022/05/25  1205.65  11.17  0.94  1194.04  1209.36  1192.90  3214710
# 2022/05/26  1215.53   9.88  0.82  1206.46  1216.10  1205.86  2934410
# 2022/05/27  1220.22   4.69  0.39  1220.25  1222.36  1214.48  2884849
# ...             ...    ...   ...      ...      ...      ...      ...
# 2023/05/17   855.59  -3.62 -0.42   859.01   860.11   853.61  1462044
# 2023/05/18   857.98   2.39  0.28   857.36   859.46   855.51  1076735
# 2023/05/19   862.43   4.45  0.52   860.00   862.44   854.28  1174625
# 2023/05/22   864.23   1.80  0.21   862.35   865.22   859.38  1061741
# 2023/05/23   861.18  -3.05 -0.35   863.86   863.99   858.44   986032
#
#                    거래대금         상장시가총액
# 일자
# 2022/05/23  10457701250  7298664191130
# 2022/05/24  11364414430  7341177703710
# 2022/05/25  20588951460  7410036495410
# 2022/05/26  18694273130  7476375804590
# 2022/05/27  18715622493  7500701282260
# ...                 ...            ...
# 2023/05/17   6607965785  5933869653255
# 2023/05/18   4899659835  5949788044340
# 2023/05/19   5414064275  5979107131335
# 2023/05/22   4886299445  5994939001010
# 2023/05/23   4529125785  5971240651400
#
# [249 rows x 9 columns]

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,249,18))
plt.plot(KRX_REITs['종가'])

# %%
adf_test_1(KRX_REITs['종가'])
# Out:
# ADF Statistics: -3.123882
# p-value: 0.024836
# Critical value:
# 	1%: -3.458
# 	5%: -2.874
# 	10%: -2.573

# %% [markdown]
# - 좀 더 강한 가정인 유의수준 0.01하에서 p-value가 0.01보다 크기 때문에  Null Hypothesis를 reject할 수 없다.
# - 따라서 non-stationary하다.

# %% [markdown]
# #### KRX 리츠 TOP10 지수 종가 로그 차분 실시

# %%
KRX_REITs['yt_종가'] = np.log(KRX_REITs['종가']) - np.log(KRX_REITs['종가'].shift(1))

# %%
KRX_REITs.dropna(inplace = True)

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,249,18))
plt.plot(KRX_REITs['yt_종가'])

# %%
adf_test_1(KRX_REITs['yt_종가'])
# Out:
# ADF Statistics: -8.181190
# p-value: 0.000000
# Critical value:
# 	1%: -3.457
# 	5%: -2.873
# 	10%: -2.573

# %% [markdown]
# - 로그 차분 후의 p-value가 매우 작기 때문에 Null Hypothesis를 reject할 수 있다.
# - 따라서 stationary하다.

# %%
KRX_REITs_df = KRX_REITs[['yt_종가']]

KRX_REITs_df
# Out:
#                yt_종가
# 일자
# 2022/05/24  0.005869
# 2022/05/25  0.009308
# 2022/05/26  0.008161
# 2022/05/27  0.003851
# 2022/05/30 -0.008452
# ...              ...
# 2023/05/17 -0.004222
# 2023/05/18  0.002789
# 2023/05/19  0.005173
# 2023/05/22  0.002085
# 2023/05/23 -0.003535
#
# [248 rows x 1 columns]

# %% [markdown]
# #### KRX 건설 지수

# %%
KRX건설지수 = pd.read_excel('KRX건설지수.xlsx')

# %%
KRX건설지수 = KRX건설지수.sort_index(ascending=False)
KRX건설지수.reset_index(drop = True, inplace = True)
KRX건설지수.set_index('일자',drop=True, inplace = True)

# %%
KRX건설지수
# Out:
#                 종가     대비   등락률      시가      고가      저가        거래량  \
# 일자
# 2022/05/23  627.13  -7.57 -1.19  636.51  636.51  623.34   10186475
# 2022/05/24  622.74  -4.39 -0.70  625.36  634.77  622.74   17066882
# 2022/05/25  632.37   9.63  1.55  628.50  635.89  622.85   11875619
# 2022/05/26  634.68   2.31  0.37  633.68  639.08  631.32    9521930
# 2022/05/27  632.63  -2.05 -0.32  642.70  642.81  629.17    8018103
# ...            ...    ...   ...     ...     ...     ...        ...
# 2023/05/17  680.59  -0.29 -0.04  677.30  682.04  674.82   13387497
# 2023/05/18  686.32   5.73  0.84  685.13  689.08  681.43   13581151
# 2023/05/19  694.64   8.32  1.21  691.43  697.89  688.22   70803404
# 2023/05/22  712.69  18.05  2.60  695.67  713.16  695.55  157088185
# 2023/05/23  719.90   7.21  1.01  717.11  729.10  716.85  182666731
#
#                     거래대금          상장시가총액
# 일자
# 2022/05/23  240870706085  45783351628290
# 2022/05/24  318643153590  45250320884230
# 2022/05/25  249881253200  46020458110225
# 2022/05/26  222173465440  46071220663305
# 2022/05/27  276870768600  45846058837480
# ...                  ...             ...
# 2023/05/17  278757935881  53981502890284
# 2023/05/18  355760394860  54609429223364
# 2023/05/19  447307161777  54627877958261
# 2023/05/22  802216877278  56239713973485
# 2023/05/23  916843406344  57113143277552
#
# [249 rows x 9 columns]

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,249,18))
plt.plot(KRX건설지수['종가'])

# %%
adf_test_1(KRX건설지수['종가'])
# Out:
# ADF Statistics: -1.097290
# p-value: 0.716152
# Critical value:
# 	1%: -3.457
# 	5%: -2.873
# 	10%: -2.573

# %% [markdown]
# - p-value가 매우 크기 때문에 Null Hypothesis를 reject할 수 없다.
# - 따라서 non-stationary하다.

# %% [markdown]
# #### KRX 건설지수 종가 로그 차분 실시

# %%
KRX건설지수['yt_건설종가'] = np.log(KRX건설지수['종가']) - np.log(KRX건설지수['종가'].shift(1))

# %%
KRX건설지수.dropna(inplace = True)

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,248,18))
plt.plot(KRX건설지수['yt_건설종가'])

# %%
adf_test_1(KRX건설지수['yt_건설종가'])
# Out:
# ADF Statistics: -9.224101
# p-value: 0.000000
# Critical value:
# 	1%: -3.457
# 	5%: -2.873
# 	10%: -2.573

# %% [markdown]
# - 로그 차분 후의 p-value가 매우 작기 때문에 Null Hypothesis를 reject할 수 있다.
# - 따라서 stationary하다.

# %%
KRX건설지수_df = KRX건설지수[['yt_건설종가']]
KRX건설지수_df
# Out:
#              yt_건설종가
# 일자
# 2022/05/24 -0.007025
# 2022/05/25  0.015346
# 2022/05/26  0.003646
# 2022/05/27 -0.003235
# 2022/05/30  0.012613
# ...              ...
# 2023/05/17 -0.000426
# 2023/05/18  0.008384
# 2023/05/19  0.012050
# 2023/05/22  0.025653
# 2023/05/23  0.010066
#
# [248 rows x 1 columns]

# %% [markdown]
# #### 장단기금리차(T10Y2Y)

# %%
장단기금리차 = pd.read_excel('T10Y2Y.xls')
장단기금리차['observation_date'] = [str(장단기금리차['observation_date'][i])[0:10] for i in range(len(장단기금리차))]
장단기금리차['observation_date'] = 장단기금리차['observation_date'].str.replace('-','/')
장단기금리차.dropna(inplace = True)
장단기금리차.reset_index(drop = True, inplace = True)
장단기금리차.set_index('observation_date',drop=True, inplace = True)

# %%
장단기금리차
# Out:
#                   T10Y2Y
# observation_date
# 2022/05/23          0.21
# 2022/05/24          0.26
# 2022/05/25          0.27
# 2022/05/26          0.29
# 2022/05/27          0.27
# ...                  ...
# 2023/05/17         -0.55
# 2023/05/18         -0.59
# 2023/05/19         -0.58
# 2023/05/22         -0.57
# 2023/05/23         -0.56
#
# [251 rows x 1 columns]

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,251,18))
plt.plot(장단기금리차['T10Y2Y'])

# %%
adf_test_1(장단기금리차['T10Y2Y'])
# Out:
# ADF Statistics: -2.579074
# p-value: 0.097400
# Critical value:
# 	1%: -3.457
# 	5%: -2.873
# 	10%: -2.573

# %% [markdown]
# - 좀 더 강한 가정인 유의수준 0.01하에서 p-value가 0.01보다 크기 때문에  Null Hypothesis를 reject할 수 없다.
# - 따라서 non-stationary하다.

# %% [markdown]
# #### 장단기금리차 차분 실시

# %%
장단기금리차['yt_T10Y2Y'] = 장단기금리차['T10Y2Y'] - 장단기금리차['T10Y2Y'].shift(1)

장단기금리차.dropna(inplace = True)

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,250,18))
plt.plot(장단기금리차['yt_T10Y2Y'])

# %%
adf_test_1(장단기금리차['yt_T10Y2Y'])
# Out:
# ADF Statistics: -9.828703
# p-value: 0.000000
# Critical value:
# 	1%: -3.457
# 	5%: -2.873
# 	10%: -2.573

# %% [markdown]
# - 차분 후의 p-value가 매우 작기 때문에 Null Hypothesis를 reject할 수 있다.
# - 따라서 stationary하다.

# %%
장단기금리차_df = 장단기금리차[['yt_T10Y2Y']]
장단기금리차_df
# Out:
#                   yt_T10Y2Y
# observation_date
# 2022/05/24             0.05
# 2022/05/25             0.01
# 2022/05/26             0.02
# 2022/05/27            -0.02
# 2022/05/31             0.05
# ...                     ...
# 2023/05/17            -0.03
# 2023/05/18            -0.04
# 2023/05/19             0.01
# 2023/05/22             0.01
# 2023/05/23             0.01
#
# [250 rows x 1 columns]

# %% [markdown]
# #### 한국은행 뉴스심리지수

# %%
BOK뉴스심리지수 = pd.read_excel('BOK뉴스심리지수.xlsx')

# %%
BOK뉴스심리지수 = BOK뉴스심리지수.sort_index(ascending=False)
BOK뉴스심리지수.reset_index(drop = True, inplace = True)
BOK뉴스심리지수.set_index('일자',drop=True, inplace = True)

BOK뉴스심리지수
# Out:
#                 지수
# 일자
# 2022/05/23  108.47
# 2022/05/24  107.77
# 2022/05/25  108.64
# 2022/05/26  109.47
# 2022/05/27  111.67
# ...            ...
# 2023/05/16   94.64
# 2023/05/17   95.60
# 2023/05/18   96.50
# 2023/05/19   99.54
# 2023/05/22  103.73
#
# [249 rows x 1 columns]

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,249,18))
plt.plot(BOK뉴스심리지수['지수'])

# %%
adf_test_1(BOK뉴스심리지수['지수'])
# Out:
# ADF Statistics: -2.766235
# p-value: 0.063261
# Critical value:
# 	1%: -3.458
# 	5%: -2.874
# 	10%: -2.573

# %% [markdown]
# - 좀 더 강한 가정인 유의수준 0.01하에서 p-value가 0.01보다 크기 때문에  Null Hypothesis를 reject할 수 없다.
# - 따라서 non-stationary하다.

# %% [markdown]
# #### 뉴스심리지수 차분 실시

# %%
BOK뉴스심리지수['yt_지수'] = BOK뉴스심리지수['지수'] - BOK뉴스심리지수['지수'].shift(1)

BOK뉴스심리지수.dropna(inplace = True)

# %%
BOK뉴스심리지수
# Out:
#                 지수  yt_지수
# 일자
# 2022/05/24  107.77  -0.70
# 2022/05/25  108.64   0.87
# 2022/05/26  109.47   0.83
# 2022/05/27  111.67   2.20
# 2022/05/30  107.97  -3.70
# ...            ...    ...
# 2023/05/16   94.64  -0.77
# 2023/05/17   95.60   0.96
# 2023/05/18   96.50   0.90
# 2023/05/19   99.54   3.04
# 2023/05/22  103.73   4.19
#
# [248 rows x 2 columns]

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,249,18))
plt.plot(BOK뉴스심리지수['yt_지수'])

# %%
adf_test_1(BOK뉴스심리지수['yt_지수'])
# Out:
# ADF Statistics: -5.818169
# p-value: 0.000000
# Critical value:
# 	1%: -3.458
# 	5%: -2.874
# 	10%: -2.573

# %% [markdown]
# - 차분 후의 p-value가 매우 작기 때문에 Null Hypothesis를 reject할 수 있다.
# - 따라서 stationary하다.

# %%
BOK뉴스심리지수_df = BOK뉴스심리지수[['yt_지수']]
BOK뉴스심리지수_df
# Out:
#             yt_지수
# 일자
# 2022/05/24  -0.70
# 2022/05/25   0.87
# 2022/05/26   0.83
# 2022/05/27   2.20
# 2022/05/30  -3.70
# ...           ...
# 2023/05/16  -0.77
# 2023/05/17   0.96
# 2023/05/18   0.90
# 2023/05/19   3.04
# 2023/05/22   4.19
#
# [248 rows x 1 columns]

# %% [markdown]
# #### Merge Data

# %%
KRX_REITs_df.reset_index(inplace = True)
KRX건설지수_df.reset_index(inplace = True)
장단기금리차_df.reset_index(inplace = True)
BOK뉴스심리지수_df.reset_index(inplace = True)

# %%
KRX_REITs_df.columns = ['Date', 'KRX리츠TOP지수']
KRX건설지수_df.columns = ['Date', 'KRX건설지수']
장단기금리차_df.columns = ['Date', 'BOK뉴스심리지수']
BOK뉴스심리지수_df.columns = ['Date', 'T10Y2Y']

# %%
df_final = pd.DataFrame()
df_final = pd.merge(KRX_REITs_df, KRX건설지수_df, how='inner',on=['Date'])
df_final = pd.merge(df_final, 장단기금리차_df, how='inner',on=['Date'])
df_final = pd.merge(df_final, BOK뉴스심리지수_df, how='inner',on=['Date'])

# %% [markdown]
# #### 최종 데이터셋

# %%
df_final
# Out:
#            Date  KRX리츠TOP지수   KRX건설지수  BOK뉴스심리지수  T10Y2Y
# 0    2022/05/24    0.005869 -0.007025       0.05   -0.70
# 1    2022/05/25    0.009308  0.015346       0.01    0.87
# 2    2022/05/26    0.008161  0.003646       0.02    0.83
# 3    2022/05/27    0.003851 -0.003235      -0.02    2.20
# 4    2022/05/31   -0.004797  0.004532       0.05    0.55
# ..          ...         ...       ...        ...     ...
# 232  2023/05/16    0.014927 -0.001658      -0.03   -0.77
# 233  2023/05/17   -0.004222 -0.000426      -0.03    0.96
# 234  2023/05/18    0.002789  0.008384      -0.04    0.90
# 235  2023/05/19    0.005173  0.012050       0.01    3.04
# 236  2023/05/22    0.002085  0.025653       0.01    4.19
#
# [237 rows x 5 columns]

# %%
df_final.describe()
# Out:
#        KRX리츠TOP지수     KRX건설지수   BOK뉴스심리지수      T10Y2Y
# count  237.000000  237.000000  237.000000  237.000000
# mean    -0.001288    0.000561   -0.002574    0.022447
# std      0.009600    0.017354    0.060364    2.234513
# min     -0.040763   -0.061227   -0.160000   -9.060000
# 25%     -0.006278   -0.010467   -0.040000   -0.920000
# 50%     -0.000934   -0.000083   -0.010000    0.150000
# 75%      0.003851    0.010252    0.030000    1.110000
# max      0.030288    0.051323    0.420000    7.810000

# %% [markdown]
# #### 4.a Provide a table for the AIC and BIC and a brief discussion of your final lag-length selection

# %%
var = VAR(df_final[['KRX리츠TOP지수','KRX건설지수','BOK뉴스심리지수','T10Y2Y']])
var.select_order(maxlags=10).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# AIC, BIC, FPE, HQIC와 같은 lag selection criteria를 종합적으로 고려해본 결과, lag 1을 선택하겠다.

# %% [markdown]
# #### 4.b Then run the final model, and paste the output from statistical package into your homework

# %%
fit = sm.tsa.VAR(df_final[['KRX리츠TOP지수','KRX건설지수','BOK뉴스심리지수','T10Y2Y']]).fit(maxlags=1)
display(fit.summary())
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 06, Jun, 2023
# Time:                     22:58:49
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -21.4024
# Nobs:                     236.000    HQIC:                  -21.5776
# Log likelihood:           1240.64    FPE:                3.78077e-10
# AIC:                     -21.6959    Det(Omega_mle):     3.47665e-10
# --------------------------------------------------------------------
# Results for equation KRX리츠TOP지수
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                -0.000864         0.000606           -1.426           0.154
# L1.KRX리츠TOP지수         0.339538         0.067945            4.997           0.000
# L1.KRX건설지수           -0.085569         0.037726           -2.268           0.023
# L1.BOK뉴스심리지수         -0.010240         0.009918           -1.032           0.302
# L1.T10Y2Y             0.000072         0.000270            0.268           0.788
# ================================================================================
#
# Results for equation KRX건설지수
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.000702         0.001153            0.609           0.543
# L1.KRX리츠TOP지수         0.076570         0.129272            0.592           0.554
# L1.KRX건설지수           -0.067972         0.071778           -0.947           0.344
# L1.BOK뉴스심리지수         -0.007449         0.018870           -0.395           0.693
# L1.T10Y2Y             0.000419         0.000514            0.816           0.415
# ================================================================================
#
# Results for equation BOK뉴스심리지수
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                -0.003733         0.003965           -0.941           0.347
# L1.KRX리츠TOP지수        -0.636596         0.444529           -1.432           0.152
# L1.KRX건설지수           -0.241844         0.246823           -0.980           0.327
# L1.BOK뉴스심리지수         -0.080857         0.064887           -1.246           0.213
# L1.T10Y2Y             0.000974         0.001766            0.552           0.581
# ================================================================================
#
# Results for equation T10Y2Y
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.029048         0.140485            0.207           0.836
# L1.KRX리츠TOP지수        14.733314        15.749391            0.935           0.350
# L1.KRX건설지수           15.968214         8.744783            1.826           0.068
# L1.BOK뉴스심리지수         -2.670648         2.298923           -1.162           0.245
# L1.T10Y2Y             0.285744         0.062570            4.567           0.000
# ================================================================================
#
# Correlation matrix of residuals
#               KRX리츠TOP지수   KRX건설지수  BOK뉴스심리지수    T10Y2Y
# KRX리츠TOP지수      1.000000  0.406424  -0.025497 -0.067519
# KRX건설지수         0.406424  1.000000  -0.051994  0.016858
# BOK뉴스심리지수      -0.025497 -0.051994   1.000000  0.017674
# T10Y2Y         -0.067519  0.016858   0.017674  1.000000

# %% [markdown]
# #### 4.c Next, using your data, test the hypothesis that variable 1 does not Granger cause variable. Test the hypothesis that variable 2 does not Granger cause variable 1. Write up a brief discussion of the meaning of your results.

# %% [markdown]
# #### Granger causality test
#
# Null Hypotesis : 한 변수가 다른 변수를 예측하는 데 도움이 되지 않는다.
# Alternative Hypotesis : 한 변수가 다른 변수를 예측하는 데 도움이 된다.

# %% [markdown]
# #### KRX건설지수 -> KRX리츠TOP지수

# %%
sample_outs_2 = grangercausalitytests(df_final[['KRX리츠TOP지수','KRX건설지수']], maxlag=3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.9728  , p=0.0267  , df_denom=233, df_num=1
# ssr based chi2 test:   chi2=5.0368  , p=0.0248  , df=1
# likelihood ratio test: chi2=4.9838  , p=0.0256  , df=1
# parameter F test:         F=4.9728  , p=0.0267  , df_denom=233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.0849  , p=0.0181  , df_denom=230, df_num=2
# ssr based chi2 test:   chi2=8.3475  , p=0.0154  , df=2
# likelihood ratio test: chi2=8.2026  , p=0.0166  , df=2
# parameter F test:         F=4.0849  , p=0.0181  , df_denom=230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.7910  , p=0.0413  , df_denom=227, df_num=3
# ssr based chi2 test:   chi2=8.6312  , p=0.0346  , df=3
# likelihood ratio test: chi2=8.4759  , p=0.0371  , df=3
# parameter F test:         F=2.7910  , p=0.0413  , df_denom=227, df_num=3

# %%
sample_outs_2[1][0]['ssr_ftest']
# Out:
# (4.972771767970279, 0.026702868901235417, 233.0, 1)

# %% [markdown]
# - Granger causality test 결과, F-statistic이 4.972이고, p-value가 유의수준 0.05하에서 0.02로 작기 때문에 Null Hypothesis를 reject할 수 있다.

# %% [markdown]
# #### KRX리츠TOP지수 -> KRX건설지수

# %%
sample_outs_2_1 = grangercausalitytests(df_final[['KRX건설지수','KRX리츠TOP지수']], maxlag=3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3141  , p=0.5757  , df_denom=233, df_num=1
# ssr based chi2 test:   chi2=0.3181  , p=0.5728  , df=1
# likelihood ratio test: chi2=0.3179  , p=0.5729  , df=1
# parameter F test:         F=0.3141  , p=0.5757  , df_denom=233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3043  , p=0.7379  , df_denom=230, df_num=2
# ssr based chi2 test:   chi2=0.6219  , p=0.7328  , df=2
# likelihood ratio test: chi2=0.6210  , p=0.7331  , df=2
# parameter F test:         F=0.3043  , p=0.7379  , df_denom=230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2160  , p=0.8852  , df_denom=227, df_num=3
# ssr based chi2 test:   chi2=0.6681  , p=0.8807  , df=3
# likelihood ratio test: chi2=0.6671  , p=0.8809  , df=3
# parameter F test:         F=0.2160  , p=0.8852  , df_denom=227, df_num=3

# %%
sample_outs_2_1[1][0]['ssr_ftest']
# Out:
# (0.31405875756021134, 0.5757386281846106, 233.0, 1)

# %% [markdown]
# - Granger causality test 결과, F-statistic이 0.314이고, p-value가 유의수준 0.05하에서 0.57으로 크기 때문에 Null Hypothesis를 reject할 수 없다.

# %% [markdown]
# 건설지수가 리츠지수에 Granger 인과영향을 주지만 리츠지수는 건설지수에 Granger 인과영향을 주지 않는다.

# %% [markdown]
# ---

# %% [markdown]
# #### BOK뉴스심리지수 -> KRX리츠TOP지수

# %%
sample_outs_3 = grangercausalitytests(df_final[['KRX리츠TOP지수','BOK뉴스심리지수']], maxlag=3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8966  , p=0.3447  , df_denom=233, df_num=1
# ssr based chi2 test:   chi2=0.9082  , p=0.3406  , df=1
# likelihood ratio test: chi2=0.9064  , p=0.3411  , df=1
# parameter F test:         F=0.8966  , p=0.3447  , df_denom=233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.0473  , p=0.3525  , df_denom=230, df_num=2
# ssr based chi2 test:   chi2=2.1402  , p=0.3430  , df=2
# likelihood ratio test: chi2=2.1305  , p=0.3446  , df=2
# parameter F test:         F=1.0473  , p=0.3525  , df_denom=230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7271  , p=0.5368  , df_denom=227, df_num=3
# ssr based chi2 test:   chi2=2.2484  , p=0.5225  , df=3
# likelihood ratio test: chi2=2.2377  , p=0.5246  , df=3
# parameter F test:         F=0.7271  , p=0.5368  , df_denom=227, df_num=3

# %%
sample_outs_3[1][0]['ssr_ftest']
# Out:
# (0.8966397821871753, 0.3446653034063928, 233.0, 1)

# %% [markdown]
# - Granger causality test 결과, F-statistic이 0.896이고, p-value가 유의수준 0.05하에서 0.344로 크기 때문에 Null Hypothesis를 reject할 수 없다.

# %% [markdown]
# #### KRX리츠TOP지수 -> BOK뉴스심리지수

# %%
sample_outs_3_1 = grangercausalitytests(df_final[['BOK뉴스심리지수','KRX리츠TOP지수']], maxlag=3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.0392  , p=0.0456  , df_denom=233, df_num=1
# ssr based chi2 test:   chi2=4.0912  , p=0.0431  , df=1
# likelihood ratio test: chi2=4.0561  , p=0.0440  , df=1
# parameter F test:         F=4.0392  , p=0.0456  , df_denom=233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.1755  , p=0.1159  , df_denom=230, df_num=2
# ssr based chi2 test:   chi2=4.4456  , p=0.1083  , df=2
# likelihood ratio test: chi2=4.4041  , p=0.1106  , df=2
# parameter F test:         F=2.1755  , p=0.1159  , df_denom=230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2784  , p=0.2826  , df_denom=227, df_num=3
# ssr based chi2 test:   chi2=3.9533  , p=0.2665  , df=3
# likelihood ratio test: chi2=3.9203  , p=0.2702  , df=3
# parameter F test:         F=1.2784  , p=0.2826  , df_denom=227, df_num=3

# %%
sample_outs_3_1[1][0]['ssr_ftest']
# Out:
# (4.039183211094756, 0.04560838209669543, 233.0, 1)

# %% [markdown]
# - Granger causality test 결과, F-statistic이 4.039이고, p-value가 유의수준 0.05하에서 0.04로 작기 때문에 Null Hypothesis를 reject할 수 있다.

# %% [markdown]
# 리츠지수가 뉴스심리지수에 Granger 인과영향을 주지만 뉴스심리지수는 리츠지수에 Granger 인과영향을 주지 않는다.

# %% [markdown]
# ---

# %% [markdown]
# #### T10Y2Y -> KRX리츠TOP지수

# %%
sample_outs_4 = grangercausalitytests(df_final[['KRX리츠TOP지수','T10Y2Y']], maxlag=3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0314  , p=0.8595  , df_denom=233, df_num=1
# ssr based chi2 test:   chi2=0.0318  , p=0.8585  , df=1
# likelihood ratio test: chi2=0.0318  , p=0.8585  , df=1
# parameter F test:         F=0.0314  , p=0.8595  , df_denom=233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2140  , p=0.8075  , df_denom=230, df_num=2
# ssr based chi2 test:   chi2=0.4374  , p=0.8036  , df=2
# likelihood ratio test: chi2=0.4370  , p=0.8037  , df=2
# parameter F test:         F=0.2140  , p=0.8075  , df_denom=230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1515  , p=0.9287  , df_denom=227, df_num=3
# ssr based chi2 test:   chi2=0.4684  , p=0.9258  , df=3
# likelihood ratio test: chi2=0.4680  , p=0.9259  , df=3
# parameter F test:         F=0.1515  , p=0.9287  , df_denom=227, df_num=3

# %%
sample_outs_4[1][0]['ssr_ftest']
# Out:
# (0.03140246449471775, 0.8594994277159832, 233.0, 1)

# %% [markdown]
# - Granger causality test 결과, F-statistic이 0.031이고, p-value가 유의수준 0.05하에서 0.85로 크기 때문에 Null Hypothesis를 reject할 수 없다.

# %% [markdown]
# #### KRX리츠TOP지수 -> T10Y2Y

# %%
sample_outs_4_1 = grangercausalitytests(df_final[['T10Y2Y','KRX리츠TOP지수']], maxlag=3)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.4181  , p=0.0658  , df_denom=233, df_num=1
# ssr based chi2 test:   chi2=3.4621  , p=0.0628  , df=1
# likelihood ratio test: chi2=3.4370  , p=0.0638  , df=1
# parameter F test:         F=3.4181  , p=0.0658  , df_denom=233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.6607  , p=0.1923  , df_denom=230, df_num=2
# ssr based chi2 test:   chi2=3.3936  , p=0.1833  , df=2
# likelihood ratio test: chi2=3.3693  , p=0.1855  , df=2
# parameter F test:         F=1.6607  , p=0.1923  , df_denom=230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6233  , p=0.1848  , df_denom=227, df_num=3
# ssr based chi2 test:   chi2=5.0200  , p=0.1703  , df=3
# likelihood ratio test: chi2=4.9669  , p=0.1742  , df=3
# parameter F test:         F=1.6233  , p=0.1848  , df_denom=227, df_num=3

# %%
sample_outs_4_1[1][0]['ssr_ftest']
# Out:
# (3.4181374678041268, 0.06575057990429199, 233.0, 1)

# %% [markdown]
# - Granger causality test 결과, F-statistic이 3.418이고, p-value가 유의수준 0.05하에서 0.06으로 크기 때문에 Null Hypothesis를 reject할 수 없다.

# %% [markdown]
# 리츠지수와 장단기금리차는 서로 Granger 인과영향을 주지 않는다.

# %% [markdown]
# #### Summary

# %% [markdown]
# - KRX리츠TOP10의 로그 차분한 수익률에 KRX 건설지수의 로그 차분한 수익률이 Granger 인과영향을 주고, 뉴스심리지수 차분 값과 장단기금리차 차분 값은 Granger 인과영향을 주지 않는다.
# - KRX리츠TOP10의 로그 차분한 수익률이 뉴스심리지수를 차분한 값에 Granger 인과영향을 준다.

# %% [markdown]
# #### 요한슨 검정

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen


def joh_output(res):
    output = pd.DataFrame([res.lr2,res.lr1],
                          index=['max_eig_stat',"trace_stat"])
    print(output.T,'\n')
    print("Critical values(90%, 95%, 99%) of max_eig_stat\n",res.cvm,'\n')
    print("Critical values(90%, 95%, 99%) of trace_stat\n",res.cvt,'\n')


# model with constant/trend (deterministic) term with lags set to 1
joh_model = coint_johansen(df_final[['KRX리츠TOP지수','KRX건설지수','BOK뉴스심리지수','T10Y2Y']],0,1) # k_ar_diff +1 = K
joh_output(joh_model)
# Out:
#    max_eig_stat  trace_stat
# 0     89.757741  287.403115
# 1     85.446507  197.645374
# 2     60.355160  112.198867
# 3     51.843707   51.843707
#
# Critical values(90%, 95%, 99%) of max_eig_stat
#  [[25.1236 27.5858 32.7172]
#  [18.8928 21.1314 25.865 ]
#  [12.2971 14.2639 18.52  ]
#  [ 2.7055  3.8415  6.6349]]
#
# Critical values(90%, 95%, 99%) of trace_stat
#  [[44.4929 47.8545 54.6815]
#  [27.0669 29.7961 35.4628]
#  [13.4294 15.4943 19.9349]
#  [ 2.7055  3.8415  6.6349]]

# %%
# 예측 및 시각화
forecast_num = 10
pred_var = fit.forecast(fit.model.endog[-1:], steps=forecast_num) # 점추정
pred_var_ci = fit.forecast_interval(fit.model.endog[-1:], steps=forecast_num) #구간추정
fit.plot_forecast(forecast_num)
plt.tight_layout()
plt.subplots_adjust(left=0.125, bottom=0.1, right=1.2, top=1, wspace=0.5, hspace=0.5)

plt.show()

# %%
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
# 임펄스반응함수 추정
fit.irf(forecast_num).plot()
plt.tight_layout()
plt.subplots_adjust(left=0.125, bottom=0.1, right=1.2, top=1, wspace=0.5, hspace=0.5)

plt.show()

# %%
var_decomp = fit.fevd(periods=10, var_decomp=None)

# %%
var_decomp.summary()
# Out:
# FEVD for KRX리츠TOP지수
#      KRX리츠TOP지수   KRX건설지수  BOK뉴스심리지수    T10Y2Y
# 0      1.000000  0.000000   0.000000  0.000000
# 1      0.976647  0.019070   0.004029  0.000254
# 2      0.975700  0.019875   0.004174  0.000252
# 3      0.975528  0.020023   0.004197  0.000252
# 4      0.975510  0.020039   0.004200  0.000252
# 5      0.975507  0.020041   0.004200  0.000252
# 6      0.975507  0.020041   0.004200  0.000252
# 7      0.975507  0.020041   0.004200  0.000252
# 8      0.975507  0.020041   0.004200  0.000252
# 9      0.975507  0.020041   0.004200  0.000252
#
# FEVD for KRX건설지수
#      KRX리츠TOP지수   KRX건설지수  BOK뉴스심리지수    T10Y2Y
# 0      0.165181  0.834819   0.000000  0.000000
# 1      0.164176  0.832652   0.000604  0.002568
# 2      0.164438  0.832269   0.000610  0.002684
# 3      0.164465  0.832225   0.000613  0.002697
# 4      0.164470  0.832219   0.000613  0.002698
# 5      0.164471  0.832218   0.000613  0.002698
# 6      0.164471  0.832218   0.000613  0.002698
# 7      0.164471  0.832218   0.000613  0.002698
# 8      0.164471  0.832218   0.000613  0.002698
# 9      0.164471  0.832218   0.000613  0.002698
#
# FEVD for BOK뉴스심리지수
#      KRX리츠TOP지수   KRX건설지수  BOK뉴스심리지수    T10Y2Y
# 0      0.000650  0.002076   0.997274  0.000000
# 1      0.016130  0.005400   0.977318  0.001152
# 2      0.016295  0.006140   0.976410  0.001154
# 3      0.016358  0.006142   0.976341  0.001158
# 4      0.016363  0.006144   0.976335  0.001159
# 5      0.016363  0.006144   0.976334  0.001159
# 6      0.016363  0.006144   0.976334  0.001159
# 7      0.016363  0.006144   0.976334  0.001159
# 8      0.016363  0.006144   0.976334  0.001159
# 9      0.016363  0.006144   0.976334  0.001159
#
# FEVD for T10Y2Y
#      KRX리츠TOP지수   KRX건설지수  BOK뉴스심리지수    T10Y2Y
# 0      0.004559  0.002351   0.000331  0.992760
# 1      0.012965  0.018958   0.004703  0.963374
# 2      0.015675  0.019393   0.005062  0.959871
# 3      0.016260  0.019384   0.005116  0.959240
# 4      0.016364  0.019381   0.005123  0.959132
# 5      0.016380  0.019381   0.005124  0.959115
# 6      0.016382  0.019381   0.005124  0.959113
# 7      0.016383  0.019381   0.005124  0.959112
# 8      0.016383  0.019381   0.005124  0.959112
# 9      0.016383  0.019381   0.005124  0.959112
