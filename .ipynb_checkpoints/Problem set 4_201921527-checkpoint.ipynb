# %% [markdown]
# # Problem set 4
#
# #### 학과 : e-비즈니스학과
# #### 학번 : 201921527
# #### 이름 : 박성우

# %% [markdown]
# ## 패키지 로드

# %%
# 기본적인 패키지 로드
import pandas as pd
import numpy as np

# 시각화 패키지 로드
import matplotlib.pyplot as plt
import statsmodels.api as sm
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# 분석 패키지 로드
from statsmodels.tsa.stattools import coint
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.vector_ar.vecm import VECM
from statsmodels.tsa.api import VAR

# ignore warning
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. The file COINT PPP.csv contains monthly values of the Japanese, Canadian, and Swiss consumer price levels and the bilateral exchange rates with the United States. The file also contains the U.S. consumer price level. The starting date for all variables is January 1974 while the availability of the variables is such that most end near the end of 2013. The price indices have been normalized to equal 100 in January 1973 and only the U.S. price index is seasonally adjusted.

# %% [markdown]
# #### Data Load

# %%
df = pd.read_csv('COINT_PPP.csv')
df.set_index(keys='DATE',drop=True, inplace = True)

df.dropna(inplace = True)

# %% [markdown]
# #### Check columns

# %%
df.columns
# Out:
# Index(['ENTRY', 'USCPI', 'CANEX', 'CANCPI', 'JAPANEX', 'JAPANCPI', 'SWEX',
#        'SWCPI'],
#       dtype='object')

# %%
df
# Out:
#                ENTRY    USCPI  CANEX   CANCPI  JAPANEX  JAPANCPI   SWEX  \
# DATE
# 01-Jan-74  22-Mar-00  117.293  0.992  121.077  299.685   135.294  3.364
# 01-Feb-74  22-Mar-00  118.546  0.977  122.057  291.658   139.706  3.176
# 01-Mar-74  22-Mar-00  119.799  0.972  123.528  287.949   140.294  3.079
# 01-Apr-74  22-Mar-00  120.551  0.968  124.508  292.197   144.118  3.027
# 01-May-74  22-Mar-00  121.805  0.962  126.959  291.430   144.706  2.917
# ...              ...      ...    ...      ...      ...       ...    ...
# 01-Aug-12  23-Mar-00  576.506  0.992  597.050   97.812   292.353  0.968
# 01-Sep-12  23-Mar-00  579.516  0.978  598.030   99.210   292.941  0.939
# 01-Oct-12  23-Mar-00  580.509  0.987  599.011   97.770   292.941  0.932
# 01-Nov-12  23-Mar-00  579.125  0.997  597.540  100.074   291.765  0.939
# 01-Dec-12  23-Mar-00  579.291  0.990  594.109  103.285   292.059  0.921
#
#              SWCPI
# DATE
# 01-Jan-74  127.774
# 01-Feb-74  126.836
# 01-Mar-74  127.431
# ...

# %% [markdown]
# #### Visualization Variables

# %%
# 사이즈 설정
plt.rcParams['figure.figsize'] = [70, 30]

# 제목 설정
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Line Graph for Three Variables')

# X축 간격 설정
plt.xticks(np.arange(0,468,25))

# 그래프 그리기
plt.plot(df.index,df.JAPANEX, label='Japan Exchange')
plt.plot(df.index,df.JAPANCPI, marker='^', label='Japan CPI')
plt.plot(df.index,df.USCPI, marker='o', label='US CPI')

# legend 폰트사이즈 설정
plt.legend(fontsize='40')
plt.show()

# %% [markdown]
# #### ADF test
# Null Hypotesis : Stationarity하지 않다. (단위근이 존재)
# Alternative Hypotesis : Stationarity하다. (단위근 존재 X)
#
# 관심 변수가 Stationary process인지 확인하기 위해 ADF test를 진행한다.

# %%
def adf_test(df):
    result  = adfuller(df.values)
    print('ADF Statistics: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical value:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key,value))

# %% [markdown]
# #### JAPANEX ADF test

# %%
adf_test(df['JAPANEX'])
# Out:
# ADF Statistics: -2.155502
# p-value: 0.222790
# Critical value:
# 	1%: -3.445
# 	5%: -2.868
# 	10%: -2.570

# %% [markdown]
# - p-value가 0.22로 유의수준 0.05보다 커 귀무가설을 기각하지 못한다.
# - 따라서 stationary process가 아니다.

# %% [markdown]
# #### JAPANCPI ADF test

# %%
adf_test(df['JAPANCPI'])
# Out:
# ADF Statistics: -3.601891
# p-value: 0.005725
# Critical value:
# 	1%: -3.445
# 	5%: -2.868
# 	10%: -2.570

# %% [markdown]
# - p-value가 0.005로 유의수준 0.05보다 작아 귀무가설을 기각한다.
# - 따라서 stationary process이다.

# %% [markdown]
# #### USCPI ADF test

# %%
adf_test(df['USCPI'])
# Out:
# ADF Statistics: -0.733380
# p-value: 0.837913
# Critical value:
# 	1%: -3.445
# 	5%: -2.868
# 	10%: -2.570

# %% [markdown]
# - p-value가 0.83로 유의수준 0.05보다 작아 귀무가설을 기각하지 못한다.
# - 따라서 stationary process가 아니다.

# %% [markdown]
# JAPANEX와 USCPI가 stationary process가 아니기 때문에 OLS를 실시하면 해당 결과가 spurious regression일 가능성이 있다.

# %% [markdown]
# #### a. Form the log of each variable. Estimate the long-run relationship between Japan and the U.S. as (1)

# %% [markdown]
# #### Create DataFrame

# %%
# 관심변수만 추출
df_a = df[['JAPANEX', 'JAPANCPI', 'USCPI']]

# 관심변수 로그 변환
df_a['L_JAPANEX'] = np.log(df_a['JAPANEX'])
df_a['L_JAPANCPI'] = np.log(df_a['JAPANCPI'])
df_a['L_USCPI'] = np.log(df_a['USCPI'])

df_a
# Out:
#            JAPANEX  JAPANCPI    USCPI  L_JAPANEX  L_JAPANCPI   L_USCPI
# DATE
# 01-Jan-74  299.685   135.294  117.293   5.702732    4.907450  4.764675
# 01-Feb-74  291.658   139.706  118.546   5.675582    4.939540  4.775301
# 01-Mar-74  287.949   140.294  119.799   5.662783    4.943740  4.785815
# 01-Apr-74  292.197   144.118  120.551   5.677428    4.970632  4.792073
# 01-May-74  291.430   144.706  121.805   5.674800    4.974704  4.802421
# ...            ...       ...      ...        ...         ...       ...
# 01-Aug-12   97.812   292.353  576.506   4.583047    5.677962  6.356986
# 01-Sep-12   99.210   292.941  579.516   4.597239    5.679971  6.362193
# 01-Oct-12   97.770   292.941  580.509   4.582618    5.679971  6.363905
# 01-Nov-12  100.074   291.765  579.125   4.605910    5.675949  6.361518
# 01-Dec-12  103.285   292.059  579.291   4.637492    5.676956  6.361805
#
# [468 rows x 6 columns]

# %% [markdown]
# #### Visualization log variables

# %%
# 사이즈 설정
plt.rcParams['figure.figsize'] = [70, 30]

# 제목 설정
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Line Graph for Three Variables')

# X축 간격 설정
plt.xticks(np.arange(0,468,25))

# 그래프 그리기
plt.plot(df.index,df_a.L_JAPANEX, label='Japan Exchange')
plt.plot(df.index,df_a.L_JAPANCPI, marker='^', label='Japan CPI')
plt.plot(df.index,df_a.L_USCPI, marker='o', label='US CPI')

# legend 폰트사이즈 설정
plt.legend(fontsize='40')
plt.show()

# %% [markdown]
# #### Split Independent Data and Target Data

# %%
X = df_a.loc[:,['L_JAPANCPI','L_USCPI']]
Y = df_a.loc[:,['L_JAPANEX']]

# 상수항 추가
X = sm.add_constant(X, has_constant = "add")

# %% [markdown]
# #### Multi Linear Regression

# %%
model = sm.OLS(Y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              L_JAPANEX   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     1165.
# Date:                Wed, 14 Jun 2023   Prob (F-statistic):          8.13e-182
# Time:                        01:58:44   Log-Likelihood:                 206.95
# No. Observations:                 468   AIC:                            -407.9
# Df Residuals:                     465   BIC:                            -395.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.9746      0.366     27.258      0.000       9.256      10.694
# ...

# %% [markdown]
# #### i. Do the point estimates of the slope coefficients seem to be consistent with long-run PPP?

# %% [markdown]
# - USCPI의 t-statistics 값은 -17.054이고 p-value가 0으로 매우 작으므로 귀무가설을 기각한다.
# - USCPI의 coefficient의 값이 음수이다.
# - USCPI가 JAPANEX에 음의 영향을 미친다.

# %% [markdown]
# #### ii. From the t-statistics, can you conclude that the Japanese CPI is not significant at the 5% level?

# %% [markdown]
# - Japan CPI의 t-statistics 값은 -0.977이고, p-value가 0.329로 매우 크므로 유의수준 0.05하에서 귀무가설을 기각하지 못한다.
# - 따라서 not significant하다.

# %% [markdown]
# ### b. Let ut denote the residuals from the long-run relationship. Use these residuals to perform the Engle-Granger test for cointegration. If you use eleven lagged changes, you should find (2)

# %% [markdown]
# #### The t-statistic on the coefficient for ut−1 is -3.44. With three variables and 457 usable observations, the 5% and 10% critical values are about -3.760 and -3.464, respectively. Do you conclude that long-run PPP fails?

# %% [markdown]
# #### Residual 구하기

# %%
resid = results.resid

# %% [markdown]
# #### Visualization Residual

# %%
plt.figure(figsize=(10,7))
resid.plot()
plt.show()

# %% [markdown]
# #### Residual에 대한 ADF test 진행

# %%
adf_test = adfuller(resid,regression='n',maxlag=11, store = False)
adf_test
# Out:
# (-3.4305204799132403,
#  0.0006200994091774181,
#  11,
#  456,
#  {'1%': -2.5706605130424744,
#   '5%': -1.9416048886604955,
#   '10%': -1.6162503284529517},
#  -2039.4183172706953)

# %% [markdown]
# - p-value가 0.0006이므로 유의수준 0.05하에서 귀무가설을 기각한다.
# - 따라서 정상성을 만족해 공적분 관계이다. 따라서 장기적인 관계를 가진다.

# %% [markdown]
# ### c. Although (at conventional significance levels) we reject the null hypothesis of long-run PPP between Japan and the United States, estimate the error-correction model for ljapanext. If you use 11 lagged changes of each variable, you should find (3)
#
# ### where ebt−1 is the residual from the equilibrium relationship above and eleven lagged changes are used for each variable. The t-statistic on the error correction term is -3.54. Which of the variable(s) can be said to be weakly exogenous?

# %%
df_coint = df[['JAPANEX', 'JAPANCPI', 'USCPI']]

# %% [markdown]
# #### coint_johansen test 진행

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def joh_output(res):
    output = pd.DataFrame([res.lr2,res.lr1],
                          index=['max_eig_stat',"trace_stat"])
    print(output.T,'\n')
    print("Critical values(90%, 95%, 99%) of max_eig_stat\n",res.cvm,'\n')
    print("Critical values(90%, 95%, 99%) of trace_stat\n",res.cvt,'\n')

joh_model = coint_johansen(df_coint,0,1)
joh_output(joh_model)
# Out:
#    max_eig_stat  trace_stat
# 0     46.305986   55.173621
# 1      8.867009    8.867635
# 2      0.000626    0.000626
#
# Critical values(90%, 95%, 99%) of max_eig_stat
#  [[18.8928 21.1314 25.865 ]
#  [12.2971 14.2639 18.52  ]
#  [ 2.7055  3.8415  6.6349]]
#
# Critical values(90%, 95%, 99%) of trace_stat
#  [[27.0669 29.7961 35.4628]
#  [13.4294 15.4943 19.9349]
#  [ 2.7055  3.8415  6.6349]]

# %% [markdown]
# - coint rank는 1로 확인되었다.

# %% [markdown]
# #### VECM 모델 추정

# %%
vecm = VECM(endog = df_a[['L_JAPANEX','L_JAPANCPI','L_USCPI']], k_ar_diff = 11, coint_rank = 1, deterministic = 'ci')
vecm_fit = vecm.fit()

# %%
vecm_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
# Det. terms outside the coint. relation & lagged endog. parameters for equation L_JAPANEX
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# L1.L_JAPANEX       0.3055      0.046      6.584      0.000       0.215       0.396
# L1.L_JAPANCPI      0.0692      0.288      0.240      0.810      -0.495       0.634
# L1.L_USCPI         0.3041      0.526      0.579      0.563      -0.726       1.334
# L2.L_JAPANEX      -0.0456      0.049     -0.938      0.348      -0.141       0.050
# L2.L_JAPANCPI     -0.0578      0.276     -0.209      0.834      -0.600       0.484
# L2.L_USCPI        -0.5296      0.591     -0.896      0.370      -1.688       0.629
# L3.L_JAPANEX       0.0446      0.048      0.920      0.357      -0.050       0.140
# L3.L_JAPANCPI     -0.3443      0.287     -1.198      0.231      -0.908       0.219
# ...

# %% [markdown]
# - USCPI가 JAPANCPI보다 coef가 더 0에 가깝기 때문에 weakly exogenous하다.

# %%
vecm_fit.predict(steps=10)
# Out:
# array([[4.66136952, 5.67460501, 6.36271879],
#        [4.66874643, 5.67248349, 6.36465089],
#        [4.68011191, 5.67474735, 6.36601257],
#        [4.68626299, 5.67571907, 6.36731066],
#        [4.68692998, 5.67636216, 6.36843291],
#        [4.68527616, 5.67394599, 6.37029937],
#        [4.68437726, 5.67330096, 6.37208659],
#        [4.68584948, 5.67329134, 6.37326186],
#        [4.68767919, 5.67467267, 6.37374712],
#        [4.6903311 , 5.67395607, 6.37409486]])

# %%
vecm_fit.plot_forecast(steps=10, n_last_obs=50);

# %% [markdown]
# ### d. [BONUS POINTS] Obtain the impulse functions using the ordering luscpii → ljapancpit → ljapanext. You should find that the U.S. price shock has little effect on the exchange rate but that a shock to the Japanese price level causes the yen to depreciate. The response of the exchange rate to its own shock is immediate and permanent.

# %%
vecm_fit.irf(10).plot()
plt.tight_layout()
plt.subplots_adjust(left=0.125, bottom=0.1, right=1.2, top=1, wspace=0.5, hspace=0.5)

plt.show()

# %% [markdown]
# - US CPI의 충격이 JAPAN Exchange에 거의 영향을 미치지 않는다.
# - JAPAN CPI의 충격은 JAPAN Exchange에 큰 음의 영향을 미친다.
# - JAPAN Exchange의 자체 충격은 즉각적이고 0으로 수렴하지 않아 영구적이다.

# %% [markdown]
# ## 2. Now, I assume that you have set your objective (theme) of your term paper. By now, you must have your data on two (X and Y , at least) or more variables in your hands. You have already held some statistical analyses based on your problem sets.

# %% [markdown]
# ### Case (i): If your variables are ALL stationary, please estimate the VAR system and interpret the results. Does this system explains your hypothesis? If so, can you make relevant prediction on your variables based on the system? Please show the predicted values of YT +1 based on the parameters of the VAR system and your data at YT .

# %% [markdown]
# #### KRX리츠TOP10지수

# %%
KRX_REITs = pd.read_excel('KRX_리츠TOP10지수.xlsx')

# %%
KRX_REITs = KRX_REITs.sort_index(ascending=False)
KRX_REITs.reset_index(drop = True, inplace = True)
KRX_REITs.set_index('일자',drop=True, inplace = True)

KRX_REITs_df = KRX_REITs[['종가']]

# %%
KRX_REITs_df
# Out:
#                  종가
# 일자
# 2022/05/23  1187.49
# 2022/05/24  1194.48
# 2022/05/25  1205.65
# 2022/05/26  1215.53
# 2022/05/27  1220.22
# ...             ...
# 2023/05/17   855.59
# 2023/05/18   857.98
# 2023/05/19   862.43
# 2023/05/22   864.23
# 2023/05/23   861.18
#
# [249 rows x 1 columns]

# %% [markdown]
# #### KRX 건설 지수

# %%
KRX건설지수 = pd.read_excel('KRX건설지수.xlsx')

# %%
KRX건설지수 = KRX건설지수.sort_index(ascending=False)
KRX건설지수.reset_index(drop = True, inplace = True)
KRX건설지수.set_index('일자',drop=True, inplace = True)

KRX건설지수_df = KRX건설지수[['종가']]

# %%
KRX건설지수_df
# Out:
#                 종가
# 일자
# 2022/05/23  627.13
# 2022/05/24  622.74
# 2022/05/25  632.37
# 2022/05/26  634.68
# 2022/05/27  632.63
# ...            ...
# 2023/05/17  680.59
# 2023/05/18  686.32
# 2023/05/19  694.64
# 2023/05/22  712.69
# 2023/05/23  719.90
#
# [249 rows x 1 columns]

# %% [markdown]
# #### 장단기금리차

# %%
KRX장단기금리차 = pd.read_excel('KRX시장금리.xlsx')
KRX장단기금리차.reset_index(drop = True, inplace = True)
KRX장단기금리차.set_index('일자',drop=True, inplace = True)

KRX장단기금리차['KRX장단기금리차'] = KRX장단기금리차['국고채(10년)'] - KRX장단기금리차['국고채(2년)']
KRX장단기금리차_df = KRX장단기금리차[['KRX장단기금리차']]

# %%
KRX장단기금리차_df
# Out:
#             KRX장단기금리차
# 일자
# 2022/05/24      0.495
# 2022/05/25      0.477
# 2022/05/26      0.519
# 2022/05/27      0.519
# 2022/05/30      0.524
# ...               ...
# 2023/05/17     -0.056
# 2023/05/18     -0.046
# 2023/05/19     -0.023
# 2023/05/22     -0.015
# 2023/05/23      0.021
#
# [249 rows x 1 columns]

# %% [markdown]
# #### 한국은행 뉴스심리지수

# %%
BOK뉴스심리지수 = pd.read_excel('BOK뉴스심리지수.xlsx')

# %%
BOK뉴스심리지수_df = BOK뉴스심리지수.sort_index(ascending=False)
BOK뉴스심리지수_df.reset_index(drop = True, inplace = True)
BOK뉴스심리지수_df.set_index('일자',drop=True, inplace = True)

# %%
BOK뉴스심리지수_df
# Out:
#                 지수
# 일자
# 2022/05/23  108.47
# 2022/05/24  107.77
# 2022/05/25  108.64
# 2022/05/26  109.47
# 2022/05/27  111.67
# ...            ...
# 2023/05/16   94.64
# 2023/05/17   95.60
# 2023/05/18   96.50
# 2023/05/19   99.54
# 2023/05/22  103.73
#
# [249 rows x 1 columns]

# %% [markdown]
# #### Merge Data

# %%
KRX_REITs_df.reset_index(inplace = True)
KRX건설지수_df.reset_index(inplace = True)
KRX장단기금리차_df.reset_index(inplace = True)
BOK뉴스심리지수_df.reset_index(inplace = True)

# %%
KRX_REITs_df.columns = ['Date', 'KRX리츠TOP10지수']
KRX건설지수_df.columns = ['Date', 'KRX건설지수']
KRX장단기금리차_df.columns = ['Date', 'KRX장단기금리차']
BOK뉴스심리지수_df.columns = ['Date', 'BOK뉴스심리지수']

# %%
df_final = pd.DataFrame()
df_final = pd.merge(KRX_REITs_df, KRX건설지수_df, how='inner',on=['Date'])
df_final = pd.merge(df_final, KRX장단기금리차_df, how='inner',on=['Date'])
df_final = pd.merge(df_final, BOK뉴스심리지수_df, how='inner',on=['Date'])

# %%
df_final.set_index(keys='Date',drop=True, inplace = True)

# %% [markdown]
# #### 최종 데이터셋

# %%
df_final
# Out:
#             KRX리츠TOP10지수  KRX건설지수  KRX장단기금리차  BOK뉴스심리지수
# Date
# 2022/05/24       1194.48   622.74      0.495     107.77
# 2022/05/25       1205.65   632.37      0.477     108.64
# 2022/05/26       1215.53   634.68      0.519     109.47
# 2022/05/27       1220.22   632.63      0.519     111.67
# 2022/05/30       1209.95   640.66      0.524     107.97
# ...                  ...      ...        ...        ...
# 2023/05/16        859.21   680.88     -0.043      94.64
# 2023/05/17        855.59   680.59     -0.056      95.60
# 2023/05/18        857.98   686.32     -0.046      96.50
# 2023/05/19        862.43   694.64     -0.023      99.54
# 2023/05/22        864.23   712.69     -0.015     103.73
#
# [247 rows x 4 columns]

# %%
df_final.describe()
# Out:
#        KRX리츠TOP10지수     KRX건설지수   KRX장단기금리차   BOK뉴스심리지수
# count    247.000000  247.000000  247.000000  247.000000
# mean     919.848421  596.505628   -0.002445   91.787530
# std      112.020337   52.086684    0.164817    7.297894
# min      761.870000  510.850000   -0.327000   74.650000
# 25%      831.915000  554.515000   -0.112000   86.505000
# 50%      872.630000  596.500000   -0.015000   92.810000
# 75%     1007.915000  621.385000    0.058000   96.550000
# max     1220.220000  750.410000    0.601000  111.670000

# %% [markdown]
# #### Visualization Variables

# %%
# 사이즈 설정
plt.rcParams['figure.figsize'] = [70, 30]

# 제목 설정
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Line Graph for Four Variables')

# X축 간격 설정
plt.xticks(np.arange(0,247,25))

# 그래프 그리기
plt.plot(df_final.index,df_final.KRX리츠TOP10지수, label='=KRX리츠TOP10지수')
plt.plot(df_final.index,df_final.KRX건설지수, marker='^', label='KRX건설지수')
plt.plot(df_final.index,df_final.KRX장단기금리차, marker='o', label='KRX장단기금리차')
plt.plot(df_final.index,df_final.BOK뉴스심리지수, marker='v', label='BOK뉴스심리지수')

# legend 폰트사이즈 설정
plt.legend(fontsize='40')
plt.show()

# %% [markdown]
# #### ADF test 진행

# %%
def adf_test(df):
    result  = adfuller(df.values)
    print('ADF Statistics: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical value:')
    for key, value in result[4].items():
        print('\t%s: %.3f' % (key,value))

# %%
adf_test(df_final['KRX리츠TOP10지수'])
# Out:
# ADF Statistics: -3.160391
# p-value: 0.022395
# Critical value:
# 	1%: -3.458
# 	5%: -2.874
# 	10%: -2.573

# %%
adf_test(df_final['KRX건설지수'])
# Out:
# ADF Statistics: -1.183600
# p-value: 0.680610
# Critical value:
# 	1%: -3.457
# 	5%: -2.873
# 	10%: -2.573

# %%
adf_test(df_final['KRX장단기금리차'])
# Out:
# ADF Statistics: -3.097665
# p-value: 0.026726
# Critical value:
# 	1%: -3.457
# 	5%: -2.873
# 	10%: -2.573

# %%
adf_test(df_final['BOK뉴스심리지수'])
# Out:
# ADF Statistics: -2.773405
# p-value: 0.062174
# Critical value:
# 	1%: -3.458
# 	5%: -2.874
# 	10%: -2.573

# %% [markdown]
# - 4가지 변수 모두 좀 더 강한 가정인 유의수준 0.01 하에서 귀무가설을 기각하지 못한다.
# - 따라서 모두 non-stationary process이다.

# %% [markdown]
# #### Non-stationary process에 대한 차분 실시

# %% [markdown]
# #### KRX리츠TOP10지수 로그수익률

# %%
df_final['KRX리츠TOP10지수_로그수익률'] = np.log(df_final['KRX리츠TOP10지수']) - np.log(df_final['KRX리츠TOP10지수'].shift(1))

df_final.dropna(inplace = True)

plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,249,18))
plt.plot(df_final['KRX리츠TOP10지수_로그수익률'])

# %%
adf_test(df_final['KRX리츠TOP10지수_로그수익률'])
# Out:
# ADF Statistics: -3.988336
# p-value: 0.001473
# Critical value:
# 	1%: -3.458
# 	5%: -2.874
# 	10%: -2.573

# %% [markdown]
# 차분 결과 stationary process로 나타났다.

# %% [markdown]
# #### KRX건설지수 로그수익률

# %%
df_final['KRX건설지수_로그수익률'] = np.log(df_final['KRX건설지수']) - np.log(df_final['KRX건설지수'].shift(1))

# %%
df_final.dropna(inplace = True)

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,248,18))
plt.plot(df_final['KRX건설지수_로그수익률'])

# %%
adf_test(df_final['KRX건설지수_로그수익률'])
# Out:
# ADF Statistics: -9.153187
# p-value: 0.000000
# Critical value:
# 	1%: -3.458
# 	5%: -2.874
# 	10%: -2.573

# %% [markdown]
# 차분 결과 stationary process로 나타났다.

# %% [markdown]
# #### 장단기금리차 차분

# %%
df_final['KRX장단기금리차_차분'] = df_final['KRX장단기금리차'] - df_final['KRX장단기금리차'].shift(1)

df_final.dropna(inplace = True)

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,250,18))
plt.plot(df_final['KRX장단기금리차'])

# %%
adf_test(df_final['KRX장단기금리차_차분'])
# Out:
# ADF Statistics: -11.050630
# p-value: 0.000000
# Critical value:
# 	1%: -3.458
# 	5%: -2.874
# 	10%: -2.573

# %% [markdown]
# 차분 결과 stationary process로 나타났다.

# %% [markdown]
# #### BOK뉴스심리지수 차분

# %%
df_final['BOK뉴스심리지수_차분'] = df_final['BOK뉴스심리지수'] - df_final['BOK뉴스심리지수'].shift(1)

df_final.dropna(inplace = True)

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,249,18))
plt.plot(df_final['BOK뉴스심리지수_차분'])

# %%
adf_test(df_final['BOK뉴스심리지수_차분'])
# Out:
# ADF Statistics: -6.832234
# p-value: 0.000000
# Critical value:
# 	1%: -3.459
# 	5%: -2.874
# 	10%: -2.573

# %% [markdown]
# 차분 결과 stationary process로 나타났다.

# %%
df_final = df_final[['KRX리츠TOP10지수_로그수익률','KRX건설지수_로그수익률','BOK뉴스심리지수_차분','KRX장단기금리차_차분']]

# %%
df_final
# Out:
#             KRX리츠TOP10지수_로그수익률  KRX건설지수_로그수익률  BOK뉴스심리지수_차분  KRX장단기금리차_차분
# Date
# 2022/05/30           -0.008452       0.012613         -3.70         0.005
# 2022/05/31           -0.004797       0.004532          0.55         0.024
# 2022/06/02            0.005788      -0.009853         -5.97         0.031
# 2022/06/03            0.000025       0.000753         -1.36        -0.024
# 2022/06/07           -0.000322      -0.021172         -6.96         0.046
# ...                        ...            ...           ...           ...
# 2023/05/16            0.014927      -0.001658         -0.77         0.002
# 2023/05/17           -0.004222      -0.000426          0.96        -0.013
# 2023/05/18            0.002789       0.008384          0.90         0.010
# 2023/05/19            0.005173       0.012050          3.04         0.023
# 2023/05/22            0.002085       0.025653          4.19         0.008
#
# [243 rows x 4 columns]

# %% [markdown]
# #### VAR 모형 추정

# %% [markdown]
# #### lag 선정

# %%
var = VAR(df_final[['KRX리츠TOP10지수_로그수익률','KRX건설지수_로그수익률','BOK뉴스심리지수_차분','KRX장단기금리차_차분']])
var.select_order(maxlags=10).summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# criteria를 기준으로 lag 1로 선정했다.

# %% [markdown]
# #### Granger Causality 분석

# %% [markdown]
# #### KRX건설지수_로그수익률 -> KRX리츠TOP10지수_로그수익률

# %%
sample_outs1 = grangercausalitytests(df_final[['KRX리츠TOP10지수_로그수익률','KRX건설지수_로그수익률']], maxlag=5)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.0342  , p=0.0029  , df_denom=239, df_num=1
# ssr based chi2 test:   chi2=9.1476  , p=0.0025  , df=1
# likelihood ratio test: chi2=8.9790  , p=0.0027  , df=1
# parameter F test:         F=9.0342  , p=0.0029  , df_denom=239, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.1187  , p=0.0067  , df_denom=236, df_num=2
# ssr based chi2 test:   chi2=10.4544 , p=0.0054  , df=2
# likelihood ratio test: chi2=10.2340 , p=0.0060  , df=2
# parameter F test:         F=5.1187  , p=0.0067  , df_denom=236, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.6043  , p=0.0141  , df_denom=233, df_num=3
# ssr based chi2 test:   chi2=11.1378 , p=0.0110  , df=3
# likelihood ratio test: chi2=10.8871 , p=0.0124  , df=3
# parameter F test:         F=3.6043  , p=0.0141  , df_denom=233, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ...

# %% [markdown]
# #### KRX리츠TOP10지수_로그수익률 -> KRX건설지수_로그수익률

# %%
sample_outs2 = grangercausalitytests(df_final[['KRX건설지수_로그수익률','KRX리츠TOP10지수_로그수익률']], maxlag=5)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8573  , p=0.3554  , df_denom=239, df_num=1
# ssr based chi2 test:   chi2=0.8680  , p=0.3515  , df=1
# likelihood ratio test: chi2=0.8665  , p=0.3519  , df=1
# parameter F test:         F=0.8573  , p=0.3554  , df_denom=239, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5859  , p=0.5574  , df_denom=236, df_num=2
# ssr based chi2 test:   chi2=1.1967  , p=0.5497  , df=2
# likelihood ratio test: chi2=1.1937  , p=0.5505  , df=2
# parameter F test:         F=0.5859  , p=0.5574  , df_denom=236, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4782  , p=0.6978  , df_denom=233, df_num=3
# ssr based chi2 test:   chi2=1.4777  , p=0.6874  , df=3
# likelihood ratio test: chi2=1.4731  , p=0.6885  , df=3
# parameter F test:         F=0.4782  , p=0.6978  , df_denom=233, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ...

# %% [markdown]
# #### BOK뉴스심리지수_차분 -> KRX리츠TOP10지수_로그수익률

# %%
sample_outs_3 = grangercausalitytests(df_final[['KRX리츠TOP10지수_로그수익률','BOK뉴스심리지수_차분']], maxlag=5)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0838  , p=0.7725  , df_denom=239, df_num=1
# ssr based chi2 test:   chi2=0.0848  , p=0.7709  , df=1
# likelihood ratio test: chi2=0.0848  , p=0.7709  , df=1
# parameter F test:         F=0.0838  , p=0.7725  , df_denom=239, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1683  , p=0.8452  , df_denom=236, df_num=2
# ssr based chi2 test:   chi2=0.3438  , p=0.8421  , df=2
# likelihood ratio test: chi2=0.3436  , p=0.8422  , df=2
# parameter F test:         F=0.1683  , p=0.8452  , df_denom=236, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1386  , p=0.9368  , df_denom=233, df_num=3
# ssr based chi2 test:   chi2=0.4283  , p=0.9343  , df=3
# likelihood ratio test: chi2=0.4279  , p=0.9344  , df=3
# parameter F test:         F=0.1386  , p=0.9368  , df_denom=233, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ...

# %% [markdown]
# #### KRX리츠TOP10지수_로그수익률 -> BOK뉴스심리지수_차분

# %%
sample_outs_4 = grangercausalitytests(df_final[['BOK뉴스심리지수_차분','KRX리츠TOP10지수_로그수익률']], maxlag=5)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.0844  , p=0.0803  , df_denom=239, df_num=1
# ssr based chi2 test:   chi2=3.1231  , p=0.0772  , df=1
# likelihood ratio test: chi2=3.1032  , p=0.0781  , df=1
# parameter F test:         F=3.0844  , p=0.0803  , df_denom=239, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.8348  , p=0.1619  , df_denom=236, df_num=2
# ssr based chi2 test:   chi2=3.7474  , p=0.1536  , df=2
# likelihood ratio test: chi2=3.7186  , p=0.1558  , df=2
# parameter F test:         F=1.8348  , p=0.1619  , df_denom=236, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4522  , p=0.2284  , df_denom=233, df_num=3
# ssr based chi2 test:   chi2=4.4874  , p=0.2134  , df=3
# likelihood ratio test: chi2=4.4460  , p=0.2172  , df=3
# parameter F test:         F=1.4522  , p=0.2284  , df_denom=233, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ...

# %% [markdown]
# #### KRX장단기금리차_차분 -> KRX리츠TOP10지수_로그수익률

# %%
sample_outs_5 = grangercausalitytests(df_final[['KRX리츠TOP10지수_로그수익률','KRX장단기금리차_차분']], maxlag=5)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0284  , p=0.8662  , df_denom=239, df_num=1
# ssr based chi2 test:   chi2=0.0288  , p=0.8653  , df=1
# likelihood ratio test: chi2=0.0288  , p=0.8653  , df=1
# parameter F test:         F=0.0284  , p=0.8662  , df_denom=239, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6484  , p=0.5238  , df_denom=236, df_num=2
# ssr based chi2 test:   chi2=1.3242  , p=0.5158  , df=2
# likelihood ratio test: chi2=1.3206  , p=0.5167  , df=2
# parameter F test:         F=0.6484  , p=0.5238  , df_denom=236, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7889  , p=0.5011  , df_denom=233, df_num=3
# ssr based chi2 test:   chi2=2.4379  , p=0.4866  , df=3
# likelihood ratio test: chi2=2.4257  , p=0.4889  , df=3
# parameter F test:         F=0.7889  , p=0.5011  , df_denom=233, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ...

# %% [markdown]
# #### KRX리츠TOP10지수_로그수익률 -> KRX장단기금리차_차분

# %%
sample_outs_6 = grangercausalitytests(df_final[['KRX장단기금리차_차분','KRX리츠TOP10지수_로그수익률']], maxlag=5)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5809  , p=0.4467  , df_denom=239, df_num=1
# ssr based chi2 test:   chi2=0.5882  , p=0.4431  , df=1
# likelihood ratio test: chi2=0.5875  , p=0.4434  , df=1
# parameter F test:         F=0.5809  , p=0.4467  , df_denom=239, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3271  , p=0.7214  , df_denom=236, df_num=2
# ssr based chi2 test:   chi2=0.6680  , p=0.7160  , df=2
# likelihood ratio test: chi2=0.6671  , p=0.7164  , df=2
# parameter F test:         F=0.3271  , p=0.7214  , df_denom=236, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2328  , p=0.8734  , df_denom=233, df_num=3
# ssr based chi2 test:   chi2=0.7195  , p=0.8686  , df=3
# likelihood ratio test: chi2=0.7184  , p=0.8689  , df=3
# parameter F test:         F=0.2328  , p=0.8734  , df_denom=233, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ...

# %% [markdown]
# #### VAR 모형

# %%
VAR_model = sm.tsa.VAR(df_final[['KRX리츠TOP10지수_로그수익률','KRX건설지수_로그수익률','BOK뉴스심리지수_차분','KRX장단기금리차_차분']]).fit(maxlags=1)
display(VAR_model.summary())
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 14, Jun, 2023
# Time:                     01:58:46
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   -22.2901
# Nobs:                     242.000    HQIC:                  -22.4623
# Log likelihood:           1378.46    FPE:                1.56425e-10
# AIC:                     -22.5785    Det(Omega_mle):     1.44138e-10
# --------------------------------------------------------------------
# Results for equation KRX리츠TOP10지수_로그수익률
# ...
#                            coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------------
# const                        -0.000843         0.000634           -1.329           0.184
# ...

# %% [markdown]
# #### 충격반응함수 추정

# %%
irf = VAR_model.irf(10) 

irf.plot()
plt.tight_layout()
plt.subplots_adjust(left=0.125, bottom=0.05, right=2, top=1.5, wspace=1, hspace=0.5)

plt.show()

# %%
var_decomp = VAR_model.fevd(periods=10, var_decomp=None)

# %%
var_decomp.summary()
# Out:
# FEVD for KRX리츠TOP10지수_로그수익률
#      KRX리츠TOP10지수_로그수익률  KRX건설지수_로그수익률  BOK뉴스심리지수_차분  KRX장단기금리차_차분
# 0              1.000000       0.000000      0.000000      0.000000
# 1              0.965416       0.034244      0.000126      0.000213
# 2              0.963083       0.036469      0.000230      0.000217
# 3              0.962813       0.036714      0.000254      0.000218
# 4              0.962786       0.036738      0.000258      0.000218
# 5              0.962783       0.036740      0.000259      0.000218
# 6              0.962783       0.036741      0.000259      0.000218
# 7              0.962783       0.036741      0.000259      0.000218
# 8              0.962783       0.036741      0.000259      0.000218
# 9              0.962783       0.036741      0.000259      0.000218
#
# FEVD for KRX건설지수_로그수익률
#      KRX리츠TOP10지수_로그수익률  KRX건설지수_로그수익률  BOK뉴스심리지수_차분  KRX장단기금리차_차분
# 0              0.186317       0.813683      0.000000      0.000000
# ...
