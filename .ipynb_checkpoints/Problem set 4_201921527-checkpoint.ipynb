# %% [markdown]
# # Problem set 4
#
# #### 학과 : e-비즈니스학과
# #### 학번 : 201921527
# #### 이름 : 박성우

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.tsa.stattools import coint
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.vector_ar.vecm import VECM
from statsmodels.tsa.vector_ar.vecm.select_coint_rank import VECM
# ignore warning
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [117], in <cell line: 10>()
#       8 from statsmodels.tsa.stattools import adfuller
#       9 from statsmodels.tsa.vector_ar.vecm import VECM
# ---> 10 from statsmodels.tsa.vector_ar.vecm.select_coint_rank import VECM
#      11 # ignore warning
#      12 import warnings
#
# ModuleNotFoundError: No module named 'statsmodels.tsa.vector_ar.vecm.select_coint_rank'; 'statsmodels.tsa.vector_ar.vecm' is not a package

# %% [markdown]
# ## 1. The file COINT PPP.csv contains monthly values of the Japanese, Canadian, and Swiss consumer price levels and the bilateral exchange rates with the United States. The file also contains the U.S. consumer price level. The starting date for all variables is January 1974 while the availability of the variables is such that most end near the end of 2013. The price indices have been normalized to equal 100 in January 1973 and only the U.S. price index is seasonally adjusted.

# %%
df = pd.read_csv('COINT_PPP.csv')

# %%
df.columns
# Out:
# Index(['DATE', 'ENTRY', 'USCPI', 'CANEX', 'CANCPI', 'JAPANEX', 'JAPANCPI',
#        'SWEX', 'SWCPI'],
#       dtype='object')

# %% [markdown]
# 날짜, ENTRY, 미국 cpi, 캐나다 환율, 캐나다 cpi, 일본 환율, 일본 cpi, 스위스 환율, 스위스 cpi

# %%
df
# Out:
#           DATE      ENTRY    USCPI  CANEX   CANCPI  JAPANEX  JAPANCPI   SWEX  \
# 0    01-Jan-74  22-Mar-00  117.293  0.992  121.077  299.685   135.294  3.364
# 1    01-Feb-74  22-Mar-00  118.546  0.977  122.057  291.658   139.706  3.176
# 2    01-Mar-74  22-Mar-00  119.799  0.972  123.528  287.949   140.294  3.079
# 3    01-Apr-74  22-Mar-00  120.551  0.968  124.508  292.197   144.118  3.027
# 4    01-May-74  22-Mar-00  121.805  0.962  126.959  291.430   144.706  2.917
# ..         ...        ...      ...    ...      ...      ...       ...    ...
# 474  01-Jul-13  23-Mar-00  584.757  1.040  603.422      NaN   294.118  0.945
# 475  01-Aug-13  23-Mar-00  585.278  1.041  603.422      NaN   295.000  0.926
# 476  01-Sep-13  23-Mar-00  586.333  1.034  604.403      NaN   295.882  0.923
# 477  01-Oct-13  23-Mar-00  585.985  1.036  602.932      NaN       NaN  0.902
# 478  01-Nov-13  23-Mar-00  586.183  1.049      NaN      NaN       NaN  0.913
#
#        SWCPI
# 0    127.774
# 1    126.836
# 2    127.431
# 3    126.662
# 4    128.886
# ..       ...
# 474  286.495
# 475  286.288
# 476  287.150
# 477  286.929
# 478      NaN
#
# [479 rows x 9 columns]

# %% [markdown]
# #### a. Form the log of each variable. Estimate the long-run relationship between Japan and the U.S. as (1)

# %% [markdown]
# #### Create DataFrame

# %%
df_a = df[['JAPANEX', 'JAPANCPI', 'USCPI']]

df_a.dropna(inplace = True)

df_a['JAPANEX'] = np.log(df_a['JAPANEX'])
df_a['JAPANCPI'] = np.log(df_a['JAPANCPI'])
df_a['USCPI'] = np.log(df_a['USCPI'])

df_a
# Out:
#       JAPANEX  JAPANCPI     USCPI
# 0    5.702732  4.907450  4.764675
# 1    5.675582  4.939540  4.775301
# 2    5.662783  4.943740  4.785815
# 3    5.677428  4.970632  4.792073
# 4    5.674800  4.974704  4.802421
# ..        ...       ...       ...
# 463  4.583047  5.677962  6.356986
# 464  4.597239  5.679971  6.362193
# 465  4.582618  5.679971  6.363905
# 466  4.605910  5.675949  6.361518
# 467  4.637492  5.676956  6.361805
#
# [468 rows x 3 columns]

# %% [markdown]
# #### Visualization Japan Exchange

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,468,15))
plt.plot(df_a['JAPANEX'])

# %% [markdown]
# #### Visualization Japan CPI

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,468,15))
plt.plot(df_a['JAPANCPI'])

# %% [markdown]
# #### Visualization US CPI

# %%
plt.figure(figsize=(20,5))
plt.xticks(np.arange(0,468,15))
plt.plot(df_a['USCPI'])

# %% [markdown]
# #### Split Independent Data and Target Data

# %%
X = df_a.loc[:,['JAPANCPI','USCPI']]
Y = df_a.loc[:,['JAPANEX']]

# 상수항 추가
X = sm.add_constant(X, has_constant = "add")

# %% [markdown]
# #### Multi Linear Regression

# %%
model = sm.OLS(Y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                JAPANEX   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     1165.
# Date:                Sat, 10 Jun 2023   Prob (F-statistic):          8.13e-182
# Time:                        20:31:49   Log-Likelihood:                 206.95
# No. Observations:                 468   AIC:                            -407.9
# Df Residuals:                     465   BIC:                            -395.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.9746      0.366     27.258      0.000       9.256      10.694
# JAPANCPI      -0.1042      0.107     -0.977      0.329      -0.314       0.105
# USCPI         -0.7682      0.045    -17.054      0.000      -0.857      -0.680
# ==============================================================================
# Omnibus:                       10.594   Durbin-Watson:                   0.031
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               10.689
# Skew:                           0.363   Prob(JB):                      0.00477
# Kurtosis:                       3.145   Cond. No.                         429.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# 미국의 인플레이션 상승이 경제 강세와 통화 긴축 가능성의 신호로 인식되면 더 높은 수익률을 추구하는 외국인 투자자를 끌어들일 수 있다.
# 이러한 미국 자산에 대한 수요 증가는 미국 달러 강세로 이어져 결과적으로 일본 엔화 가치 하락으로 이어질 수 있다.

# %% [markdown]
# #### ii. From the t-statistics, can you conclude that the Japanese CPI is not significant at the 5% level?

# %% [markdown]
# Japan CPI의 t-statistics 값은 -0.977이고, p-value가 0.329로 매우 크므로 유의수준 0.05하에서 귀무가설을 기각하지 못한다.
# 따라서 not significant하다.

# %% [markdown]
# ### b. Let ut denote the residuals from the long-run relationship. Use these residuals to perform the Engle-Granger test for cointegration. If you use eleven lagged changes, you should find (2)

# %% [markdown]
# #### The t-statistic on the coefficient for ut−1 is -3.44. With three variables and 457 usable observations, the 5% and 10% critical values are about -3.760 and -3.464, respectively. Do you conclude that long-run PPP fails?

# %%
resid = results.resid

# %%
adf_test = adfuller(resid,regression='n',maxlag=11, store = False)
adf_test
# Out:
# (-3.4305204799132403,
#  0.0006200994091774181,
#  11,
#  456,
#  {'1%': -2.5706605130424744,
#   '5%': -1.9416048886604955,
#   '10%': -1.6162503284529517},
#  -2039.4183172706953)

# %% [markdown]
# p-value가 0.0006이므로 유의수준 0.05하에서 귀무가설을 기각한다. 따라서 정상성을 만족해 공적분 관계이다. 장기적인 관계를 가진다.

# %%
# 잔차 시각화
plt.figure(figsize=(10,7))
resid.plot()
plt.show()

# %% [markdown]
# ### c. Although (at conventional significance levels) we reject the null hypothesis of long-run PPP between Japan and the United States, estimate the error-correction model for ljapanext. If you use 11 lagged changes of each variable, you should find (3)
#
# ### where ebt−1 is the residual from the equilibrium relationship above and eleven lagged changes are used for each variable. The t-statistic on the error correction term is -3.54. Which of the variable(s) can be said to be weakly exogenous?

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen


def joh_output(res):
    output = pd.DataFrame([res.lr2,res.lr1],
                          index=['max_eig_stat',"trace_stat"])
    print(output.T,'\n')
    print("Critical values(90%, 95%, 99%) of max_eig_stat\n",res.cvm,'\n')
    print("Critical values(90%, 95%, 99%) of trace_stat\n",res.cvt,'\n')


# model with constant/trend (deterministic) term with lags set to 1
joh_model = coint_johansen(df_a,0,1) # k_ar_diff +1 = K
joh_output(joh_model)
# Out:
#    max_eig_stat  trace_stat
# 0     78.053771   91.000261
# 1      9.492677   12.946489
# 2      3.453812    3.453812
#
# Critical values(90%, 95%, 99%) of max_eig_stat
#  [[18.8928 21.1314 25.865 ]
#  [12.2971 14.2639 18.52  ]
#  [ 2.7055  3.8415  6.6349]]
#
# Critical values(90%, 95%, 99%) of trace_stat
#  [[27.0669 29.7961 35.4628]
#  [13.4294 15.4943 19.9349]
#  [ 2.7055  3.8415  6.6349]]

# %%
vecm = VECM(endog = df_a[['USCPI','JAPANCPI','JAPANEX']], k_ar_diff = 11, coint_rank = 1, deterministic = 'ci')
vecm_fit = vecm.fit()

# %%
vecm_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
# Det. terms outside the coint. relation & lagged endog. parameters for equation USCPI
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# L1.USCPI         0.5307      0.047     11.302      0.000       0.439       0.623
# L1.JAPANCPI  -1.984e-05      0.026     -0.001      0.999      -0.050       0.050
# L1.JAPANEX      -0.0024      0.004     -0.572      0.568      -0.010       0.006
# L2.USCPI        -0.0986      0.053     -1.868      0.062      -0.202       0.005
# L2.JAPANCPI     -0.0521      0.025     -2.109      0.035      -0.100      -0.004
# L2.JAPANEX       0.0011      0.004      0.254      0.800      -0.007       0.010
# L3.USCPI         0.0473      0.053      0.897      0.370      -0.056       0.151
# L3.JAPANCPI     -0.0505      0.026     -1.967      0.049      -0.101      -0.000
# L3.JAPANEX       0.0035      0.004      0.815      0.415      -0.005       0.012
# L4.USCPI         0.0597      0.053      1.135      0.256      -0.043       0.163
# L4.JAPANCPI     -0.0389      0.026     -1.509      0.131      -0.089       0.012
# L4.JAPANEX      -0.0121      0.004     -2.809      0.005      -0.021      -0.004
# L5.USCPI         0.0079      0.053      0.150      0.880      -0.095       0.111
# L5.JAPANCPI     -0.0566      0.025     -2.224      0.026      -0.107      -0.007
# L5.JAPANEX       0.0043      0.004      0.991      0.322      -0.004       0.013
# L6.USCPI         0.0866      0.052      1.654      0.098      -0.016       0.189
# L6.JAPANCPI     -0.0629      0.026     -2.455      0.014      -0.113      -0.013
# L6.JAPANEX       0.0007      0.004      0.164      0.870      -0.008       0.009
# L7.USCPI         0.0622      0.053      1.185      0.236      -0.041       0.165
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0006      0.000     -4.141      0.000      -0.001      -0.000
#               Loading coefficients (alpha) for equation JAPANCPI
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0014      0.000     -5.214      0.000      -0.002      -0.001
#               Loading coefficients (alpha) for equation JAPANEX
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ec1           -0.0015      0.002     -0.874      0.382      -0.005       0.002
#           Cointegration relations for loading-coefficients-column 1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# beta.1         1.0000          0          0      0.000       1.000       1.000
# beta.2         8.1370      1.769      4.600      0.000       4.670      11.604
# beta.3         0.8408      0.597      1.409      0.159      -0.329       2.010
# const        -56.0694     11.943     -4.695      0.000     -79.476     -32.662
# ==============================================================================
# """

# %%
vecm_fit.predict(steps=10)
# Out:
# array([[6.36271879, 5.67460501, 4.66136952],
#        [6.36465089, 5.67248349, 4.66874643],
#        [6.36601257, 5.67474735, 4.68011191],
#        [6.36731066, 5.67571907, 4.68626299],
#        [6.36843291, 5.67636216, 4.68692998],
#        [6.37029937, 5.67394599, 4.68527616],
#        [6.37208659, 5.67330096, 4.68437726],
#        [6.37326186, 5.67329134, 4.68584948],
#        [6.37374712, 5.67467267, 4.68767919],
#        [6.37409486, 5.67395607, 4.6903311 ]])

# %%
vecm_fit.plot_forecast(steps=10, n_last_obs=50);

# %% [markdown]
# ### d. [BONUS POINTS] Obtain the impulse functions using the ordering luscpii → ljapancpit → ljapanext. You should find that the U.S. price shock has little effect on the exchange rate but that a shock to the Japanese price level causes the yen to depreciate. The response of the exchange rate to its own shock is immediate and permanent.

# %%
# 임펄스반응함수 추정
vecm_fit.irf(10).plot()
plt.tight_layout()
plt.subplots_adjust(left=0.125, bottom=0.1, right=1.2, top=1, wspace=0.5, hspace=0.5)

plt.show()

# %% [markdown]
# USCPI -> JAPANEX / JAPANCPI -> JAPANEX

# %% [markdown]
# ## 2. Now, I assume that you have set your objective (theme) of your term paper. By now, you must have your data on two (X and Y , at least) or more variables in your hands. You have already held some statistical analyses based on your problem sets.

# %% [markdown]
# ### Case (i): If your variables are ALL stationary, please estimate the VAR system and interpret the results. Does this system explains your hypothesis? If so, can you make relevant prediction on your variables based on the system? Please show the predicted values of YT +1 based on the parameters of the VAR system and your data at YT .

# %% [markdown]
# ### Case (ii): If your variables are unit root processes, I(1), please conduct the cointegration test (Engle-Granger test or Johansen’s trace test). Based on the results, please decide whether you estimate the error correction model or the VAR system with first-differenced] data. If you can estimate the error correction model, please report the estimation results and interpret them. Is your hypothesis supported by the results? Explain.

# %%
import pandas as pd

# %%
KRX_REITs = pd.read_excel('KRX_리츠TOP10지수.xlsx')

KRX_REITs = KRX_REITs.sort_index(ascending=False)
KRX_REITs.reset_index(drop = True, inplace = True)
KRX_REITs.set_index('일자',drop=True, inplace = True)

KRX_REITs_df = KRX_REITs[['종가']]

# %%
KRX건설지수 = pd.read_excel('KRX건설지수.xlsx')

KRX건설지수 = KRX건설지수.sort_index(ascending=False)
KRX건설지수.reset_index(drop = True, inplace = True)
KRX건설지수.set_index('일자',drop=True, inplace = True)

KRX건설지수_df = KRX건설지수[['종가']]

# %%
BOK뉴스심리지수 = pd.read_excel('BOK뉴스심리지수.xlsx')

BOK뉴스심리지수 = BOK뉴스심리지수.sort_index(ascending=False)
BOK뉴스심리지수.reset_index(drop = True, inplace = True)
BOK뉴스심리지수.set_index('일자',drop=True, inplace = True)

# %%
장단기금리차 = pd.read_excel('T10Y2Y.xls')
장단기금리차['observation_date'] = [str(장단기금리차['observation_date'][i])[0:10] for i in range(len(장단기금리차))]
장단기금리차['observation_date'] = 장단기금리차['observation_date'].str.replace('-','/')
장단기금리차.dropna(inplace = True)
장단기금리차.reset_index(drop = True, inplace = True)
장단기금리차.set_index('observation_date',drop=True, inplace = True)

# %%
KRX_REITs_df.reset_index(inplace = True)
KRX건설지수_df.reset_index(inplace = True)
장단기금리차.reset_index(inplace = True)
BOK뉴스심리지수.reset_index(inplace = True)

# %%
KRX_REITs_df.columns = ['Date', 'KRX리츠TOP지수']
KRX건설지수_df.columns = ['Date', 'KRX건설지수']
장단기금리차.columns = ['Date', 'BOK뉴스심리지수']
BOK뉴스심리지수.columns = ['Date', 'T10Y2Y']

# %%
df_final = pd.DataFrame()
df_final = pd.merge(KRX_REITs_df, KRX건설지수_df, how='inner',on=['Date'])
df_final = pd.merge(df_final, BOK뉴스심리지수, how='inner',on=['Date'])
df_final = pd.merge(df_final, 장단기금리차, how='inner',on=['Date'])

# %%
df_final
# Out:
#            Date  KRX리츠TOP지수  KRX건설지수  T10Y2Y  BOK뉴스심리지수
# 0    2022/05/23     1187.49   627.13  108.47       0.21
# 1    2022/05/24     1194.48   622.74  107.77       0.26
# 2    2022/05/25     1205.65   632.37  108.64       0.27
# 3    2022/05/26     1215.53   634.68  109.47       0.29
# 4    2022/05/27     1220.22   632.63  111.67       0.27
# ..          ...         ...      ...     ...        ...
# 233  2023/05/16      859.21   680.88   94.64      -0.52
# 234  2023/05/17      855.59   680.59   95.60      -0.55
# 235  2023/05/18      857.98   686.32   96.50      -0.59
# 236  2023/05/19      862.43   694.64   99.54      -0.58
# 237  2023/05/22      864.23   712.69  103.73      -0.57
#
# [238 rows x 5 columns]

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

# %%
def joh_output(res):
    output = pd.DataFrame([res.lr2,res.lr1],
                          index=['max_eig_stat',"trace_stat"])
    print(output.T,'\n')
    print("Critical values(90%, 95%, 99%) of max_eig_stat\n",res.cvm,'\n')
    print("Critical values(90%, 95%, 99%) of trace_stat\n",res.cvt,'\n')


# model with constant/trend (deterministic) term with lags set to 1
joh_model = coint_johansen(df_final[['KRX리츠TOP지수','KRX건설지수','BOK뉴스심리지수','T10Y2Y']],0,1) # k_ar_diff +1 = K
joh_output(joh_model)
# Out:
#    max_eig_stat  trace_stat
# 0     37.235065   65.131099
# 1     14.862405   27.896034
# 2     10.597136   13.033629
# 3      2.436493    2.436493
#
# Critical values(90%, 95%, 99%) of max_eig_stat
#  [[25.1236 27.5858 32.7172]
#  [18.8928 21.1314 25.865 ]
#  [12.2971 14.2639 18.52  ]
#  [ 2.7055  3.8415  6.6349]]
#
# Critical values(90%, 95%, 99%) of trace_stat
#  [[44.4929 47.8545 54.6815]
#  [27.0669 29.7961 35.4628]
#  [13.4294 15.4943 19.9349]
#  [ 2.7055  3.8415  6.6349]]
